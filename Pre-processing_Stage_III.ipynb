# %% [markdown]
# # <div style = "padding: 20px; border-radius: 5px; background-color: #EA80FC;color: white"><center>PRE-PROCESSING STAGE-III - DATASET A and B</center></DIV>

# %% [markdown]
# ## SCOPE

# %% [markdown]
# * The scope of this stage of pre-processing is
#     * to revisit the datasets from pre-processing Stage-II and check the columns, format and datatype.
#     * Clean if required.
#     * combine the datasets and remove duplicates if any.

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
# importing required libraries

import polars as pl
import numpy as np

# %% [markdown]
# ## OVERVIEW DATA - Dataset A and B

# %%
# laoding dataset A
overview_A = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\overview_A.csv')

# %%
# laoding dataset B
overview_B = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\overview_B.csv')

# %% [markdown]
# * **CHECKING IF COLUMN NAMES AND DATA MATCH FOR DATASETS A and B, and combining them**

# %%
# checking the no. of columns in A and B datasets

print("dataset A columns: ", len(overview_A.columns))
print("dataset B columns: ", len(overview_B.columns))
# Out:
# dataset A columns:  16
# dataset B columns:  16

# %%
# checking shape
print("dataset A shape: ", overview_A.shape)
print("dataset B shape: ", overview_B.shape)
# Out:
# dataset A shape:  (59708, 16)
# dataset B shape:  (30274, 16)

# %% [markdown]
# * both of them have the same no. of columns
# * lets check if they have the same columns

# %%
overview_A.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'fuelName',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission']

# %%
overview_B.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'fuelName',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'cityName',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'State',
#  'transmission']

# %% [markdown]
# * there is a difference in the column names, and have to corrected
# * correcting for overview_B

# %%
overview_B = overview_B.rename(
                                {'cityName':'city','State':'state'}
                             )

# %%
# checking which columns of A and B are not available in both

print(set(overview_A.columns).difference(set(overview_A.columns))) # extra columns in dataset A
print(set(overview_B.columns).difference(set(overview_B.columns))) # extra columns in dataset B
# Out:
# set()
# set()

# %% [markdown]
# * both the datasets have the same columns

# %%
# checking dataset A 
overview_A.head(2)
# Out:
# shape: (2, 16)
# ┌───────────┬──────────────────┬────────────┬──────────┬───┬─────────┬───────────────┬──────────────────┬──────────────┐
# │ profileId ┆ vehicle          ┆ kilometers ┆ fuelName ┆ … ┆ price   ┆ modelName     ┆ state            ┆ transmission │
# │ ---       ┆ ---              ┆ ---        ┆ ---      ┆   ┆ ---     ┆ ---           ┆ ---              ┆ ---          │
# │ str       ┆ str              ┆ f64        ┆ str      ┆   ┆ i64     ┆ str           ┆ str              ┆ str          │
# ╞═══════════╪══════════════════╪════════════╪══════════╪═══╪═════════╪═══════════════╪══════════════════╪══════════════╡
# │ S2725575  ┆ Mercedes-Benz    ┆ 6000.0     ┆ Diesel + ┆ … ┆ 7500000 ┆ GLE           ┆ Andaman and      ┆ Automatic    │
# │           ┆ GLE 300d 4MATIC  ┆            ┆ Diesel   ┆   ┆         ┆               ┆ Nicobar Islands  ┆              │
# ...

# %%
overview_B.head(2)
# Out:
# shape: (2, 16)
# ┌───────────┬─────────────────────────────┬────────────┬──────────┬───┬─────────┬───────────┬───────────┬──────────────┐
# │ profileId ┆ vehicle                     ┆ kilometers ┆ fuelName ┆ … ┆ price   ┆ modelName ┆ state     ┆ transmission │
# │ ---       ┆ ---                         ┆ ---        ┆ ---      ┆   ┆ ---     ┆ ---       ┆ ---       ┆ ---          │
# │ str       ┆ str                         ┆ f64        ┆ str      ┆   ┆ i64     ┆ str       ┆ str       ┆ str          │
# ╞═══════════╪═════════════════════════════╪════════════╪══════════╪═══╪═════════╪═══════════╪═══════════╪══════════════╡
# │ D4135089  ┆ Tata Harrier XZ Dark        ┆ 39420.0    ┆ Diesel   ┆ … ┆ 1895000 ┆ Harrier   ┆ Karnataka ┆ Manual       │
# │           ┆ Edition                     ┆            ┆          ┆   ┆         ┆           ┆           ┆              │
# ...

# %%
print (overview_A.columns == overview_B.columns)
# Out:
# True

# %%
print (overview_A, '\n',overview_B)
# Out:
# shape: (59_708, 16)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬─────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ fuelName      ┆ … ┆ price   ┆ modelName     ┆ state         ┆ transmission │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ ---     ┆ ---           ┆ ---           ┆ ---          │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ i64     ┆ str           ┆ str           ┆ str          │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═════════╪═══════════════╪═══════════════╪══════════════╡
# │ S2725575  ┆ Mercedes-Benz  ┆ 6000.0     ┆ Diesel +      ┆ … ┆ 7500000 ┆ GLE           ┆ Andaman and   ┆ Automatic    │
# │           ┆ GLE 300d       ┆            ┆ Diesel        ┆   ┆         ┆               ┆ Nicobar       ┆              │
# ...

# %% [markdown]
# ## SPECIFICATION DATA - Dataset A and B

# %% [markdown]
# ### ENGINE

# %%
# reading engine specification datasets A and B

specs_engine_A = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Engine_A.csv')
specs_engine_B = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Engine_B.csv')

# %% [markdown]
# * **CHECKING IF COLUMN NAMES AND DATA MATCH FOR DATASETS A and B, and combining them**

# %%
# checking the no. of columns in A and B datasets

print("dataset A columns: ", len(specs_engine_A.columns))
print("dataset B columns: ", len(specs_engine_B.columns))
# Out:
# dataset A columns:  10
# dataset B columns:  10

# %% [markdown]
# * no. of columns match
# * checking if the column names match

# %%
specs_engine_A.columns
# Out:
# ['profileId',
#  'vehicle',
#  'fuel',
#  'Mileage (ARAI)',
#  'transmission',
#  'Displacement',
#  'maxPower_(bhp)',
#  'maxPowerrpm',
#  'maxTorque_(Nm)',
#  'maxTorquerpm']

# %%
specs_engine_B.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Mileage (ARAI)',
#  'Fuel',
#  'transmission',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm']

# %% [markdown]
# * mismatch in column names of A and B

# %%
# checking which columns of A and B are not available in both

print(set(specs_engine_A.columns).difference(set(specs_engine_B.columns))) # extra columns in dataset A
print(set(specs_engine_B.columns).difference(set(specs_engine_A.columns))) # extra columns in dataset B
# Out:
# {'Displacement', 'maxTorquerpm', 'maxPower_(bhp)', 'fuel', 'maxTorque_(Nm)', 'maxPowerrpm'}
# {'Fuel', 'Max_Torque_at_rpm', 'Displacement_(cc)', 'Max_Torque_(Nm)', 'Max_Power_(bhp)', 'Max_Power_at_rpm'}

# %% [markdown]
# * change column names of specs_engine_A

# %%
specs_engine_A = specs_engine_A.rename({
                                     'fuel':'Fuel',
                                     'Displacement':'Displacement_(cc)',
                                     'maxPower_(bhp)':'Max_Power_(bhp)',
                                     'maxPowerrpm':'Max_Power_at_rpm',
                                     'maxTorque_(Nm)':'Max_Torque_(Nm)',
                                     'maxTorquerpm':'Max_Torque_at_rpm'
                                    })

# %%
# checking which columns of A and B are not available in both

print(set(specs_engine_A.columns).difference(set(specs_engine_B.columns))) # extra columns in dataset A
print(set(specs_engine_B.columns).difference(set(specs_engine_A.columns))) # extra columns in dataset B
# Out:
# set()
# set()

# %%
specs_engine_A.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Fuel',
#  'Mileage (ARAI)',
#  'transmission',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm']

# %%
specs_engine_B.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Mileage (ARAI)',
#  'Fuel',
#  'transmission',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm']

# %%
specs_engine_A.head(2)
# Out:
# shape: (2, 10)
# ┌───────────┬────────────────┬────────┬─────────┬───┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ Fuel   ┆ Mileage ┆ … ┆ Max_Power_(bhp ┆ Max_Power_at_r ┆ Max_Torque_(Nm ┆ Max_Torque_at │
# │ ---       ┆ ---            ┆ ---    ┆ (ARAI)  ┆   ┆ )              ┆ pm             ┆ )              ┆ _rpm          │
# │ str       ┆ str            ┆ str    ┆ ---     ┆   ┆ ---            ┆ ---            ┆ ---            ┆ ---           │
# │           ┆                ┆        ┆ f64     ┆   ┆ f64            ┆ str            ┆ f64            ┆ str           │
# ╞═══════════╪════════════════╪════════╪═════════╪═══╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ D1820959  ┆ Hyundai i10    ┆ Petrol ┆ 16.95   ┆ … ┆ 79.0           ┆  6000 rpm      ┆ 112.7619       ┆  4000 rpm     │
# ...

# %%
specs_engine_B.head(2)
# Out:
# shape: (2, 10)
# ┌───────────┬────────────────┬─────────┬────────┬───┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ Mileage ┆ Fuel   ┆ … ┆ Max_Torque_(Nm ┆ Max_Torque_at_ ┆ Max_Power_(bhp ┆ Max_Power_at_ │
# │ ---       ┆ ---            ┆ (ARAI)  ┆ ---    ┆   ┆ )              ┆ rpm            ┆ )              ┆ rpm           │
# │ str       ┆ str            ┆ ---     ┆ str    ┆   ┆ ---            ┆ ---            ┆ ---            ┆ ---           │
# │           ┆                ┆ f64     ┆        ┆   ┆ f64            ┆ f64            ┆ f64            ┆ f64           │
# ╞═══════════╪════════════════╪═════════╪════════╪═══╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ D4135089  ┆ Tata Harrier   ┆ 16.3    ┆ Diesel ┆ … ┆ 350.0          ┆ 1750.0         ┆ 168.0          ┆ 3750.0        │
# ...

# %% [markdown]
# ### DIMENSIONS

# %%
# reading engine specification datasets A and B

specs_dimensions_A = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Dimensions_A.csv')
specs_dimensions_B = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Dimensions_B.csv')

# %% [markdown]
# * **CHECKING IF COLUMN NAMES AND DATA MATCH FOR DATASETS A and B, and combining them**

# %%
# checking the no. of columns in A and B datasets

print("dataset A columns: ", len(specs_dimensions_A.columns))
print("dataset B columns: ", len(specs_dimensions_B.columns))
# Out:
# dataset A columns:  8
# dataset B columns:  8

# %% [markdown]
# * no. of columns match
# * checking if the column names match

# %%
specs_dimensions_A.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)']

# %%
specs_dimensions_B.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Length_(mm)',
#  'Width_(mm)',
#  'Kerb_Weight_(mm)',
#  'Wheelbase_(mm)',
#  'Height_(mm)',
#  'Ground_Clearance_(mm)']

# %% [markdown]
# * there are no mismatch in column names

# %%
# checking which columns of A and B are not available in both

print(set(specs_dimensions_A.columns).difference(set(specs_dimensions_B.columns))) # extra columns in dataset A
print(set(specs_dimensions_B.columns).difference(set(specs_dimensions_A.columns))) # extra columns in dataset B
# Out:
# set()
# set()

# %%
specs_dimensions_A.head(2)
# Out:
# shape: (2, 8)
# ┌───────────┬────────────────┬────────────────┬─────────────┬───────────────┬─────────────┬───────────────┬────────────┐
# │ profileId ┆ vehicle        ┆ Ground_Clearan ┆ Height_(mm) ┆ Kerb_Weight_( ┆ Length_(mm) ┆ Wheelbase_(mm ┆ Width_(mm) │
# │ ---       ┆ ---            ┆ ce_(mm)        ┆ ---         ┆ mm)           ┆ ---         ┆ )             ┆ ---        │
# │ str       ┆ str            ┆ ---            ┆ f64         ┆ ---           ┆ f64         ┆ ---           ┆ f64        │
# │           ┆                ┆ f64            ┆             ┆ f64           ┆             ┆ f64           ┆            │
# ╞═══════════╪════════════════╪════════════════╪═════════════╪═══════════════╪═════════════╪═══════════════╪════════════╡
# │ D1820959  ┆ Hyundai i10    ┆ 165.0          ┆ 1550.0      ┆ null          ┆ 3585.0      ┆ 2380.0        ┆ 1595.0     │
# │           ┆ Sportz 1.2 AT  ┆                ┆             ┆               ┆             ┆               ┆            │
# ...

# %%
specs_dimensions_B.head(2)
# Out:
# shape: (2, 8)
# ┌───────────┬────────────────┬─────────────┬────────────┬────────────────┬───────────────┬─────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ Length_(mm) ┆ Width_(mm) ┆ Kerb_Weight_(m ┆ Wheelbase_(mm ┆ Height_(mm) ┆ Ground_Cleara │
# │ ---       ┆ ---            ┆ ---         ┆ ---        ┆ m)             ┆ )             ┆ ---         ┆ nce_(mm)      │
# │ str       ┆ str            ┆ f64         ┆ f64        ┆ ---            ┆ ---           ┆ f64         ┆ ---           │
# │           ┆                ┆             ┆            ┆ f64            ┆ f64           ┆             ┆ f64           │
# ╞═══════════╪════════════════╪═════════════╪════════════╪════════════════╪═══════════════╪═════════════╪═══════════════╡
# │ D4170559  ┆ Jeep Compass   ┆ 4395.0      ┆ 1818.0     ┆ 1584.0         ┆ 2636.0        ┆ 1640.0      ┆ null          │
# │           ┆ Limited 2.0    ┆             ┆            ┆                ┆               ┆             ┆               │
# ...

# %% [markdown]
# ### CAPACITY

# %%
# reading engine specification datasets A and B

specs_capacity_A = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Capacity_A.csv')
specs_capacity_B = pl.read_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-II\specs_Capacity_B.csv')

# %% [markdown]
# * **CHECKING IF COLUMN NAMES AND DATA MATCH FOR DATASETS A and B, and combining them**

# %%
# checking the no. of columns in A and B datasets

print("dataset A columns: ", len(specs_capacity_A.columns))
print("dataset B columns: ", len(specs_capacity_B.columns))
# Out:
# dataset A columns:  7
# dataset B columns:  7

# %% [markdown]
# * no. of columns match
# * checking if the column names match

# %%
specs_capacity_A.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Bootspace_(litres)',
#  'Doors',
#  'Fuel_Tank_Capacity_(litres)',
#  'Seating_Rows_(rows)',
#  'Seating_Capacity_(persons)']

# %%
specs_capacity_B.columns
# Out:
# ['profileId',
#  'vehicle',
#  'Fuel_Tank_Capacity_(litres)',
#  'Doors',
#  'Seating_Capacity_(persons)',
#  'Seating_Rows_(rows)',
#  'Bootspace_(litres)']

# %% [markdown]
# * there are no mismatch in column names

# %%
# checking which columns of A and B are not available in both

print(set(specs_capacity_A.columns).difference(set(specs_capacity_B.columns))) # extra columns in dataset A
print(set(specs_capacity_B.columns).difference(set(specs_capacity_A.columns))) # extra columns in dataset B
# Out:
# set()
# set()

# %%
specs_capacity_A.head(2)
# Out:
# shape: (2, 7)
# ┌───────────┬───────────────────┬───────────────────┬───────┬───────────────────┬───────────────────┬──────────────────┐
# │ profileId ┆ vehicle           ┆ Bootspace_(litres ┆ Doors ┆ Fuel_Tank_Capacit ┆ Seating_Rows_(row ┆ Seating_Capacity │
# │ ---       ┆ ---               ┆ )                 ┆ ---   ┆ y_(litres)        ┆ s)                ┆ _(persons)       │
# │ str       ┆ str               ┆ ---               ┆ i64   ┆ ---               ┆ ---               ┆ ---              │
# │           ┆                   ┆ f64               ┆       ┆ f64               ┆ i64               ┆ i64              │
# ╞═══════════╪═══════════════════╪═══════════════════╪═══════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ D1820959  ┆ Hyundai i10       ┆ null              ┆ 5     ┆ 35.0              ┆ 2                 ┆ 5                │
# │           ┆ Sportz 1.2 AT     ┆                   ┆       ┆                   ┆                   ┆                  │
# ...

# %%
specs_capacity_B.head(2)
# Out:
# shape: (2, 7)
# ┌───────────┬───────────────────┬───────────────────┬───────┬───────────────────┬───────────────────┬──────────────────┐
# │ profileId ┆ vehicle           ┆ Fuel_Tank_Capacit ┆ Doors ┆ Seating_Capacity_ ┆ Seating_Rows_(row ┆ Bootspace_(litre │
# │ ---       ┆ ---               ┆ y_(litres)        ┆ ---   ┆ (persons)         ┆ s)                ┆ s)               │
# │ str       ┆ str               ┆ ---               ┆ i64   ┆ ---               ┆ ---               ┆ ---              │
# │           ┆                   ┆ f64               ┆       ┆ i64               ┆ i64               ┆ i64              │
# ╞═══════════╪═══════════════════╪═══════════════════╪═══════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ D4135089  ┆ Tata Harrier XZ   ┆ 50.0              ┆ 5     ┆ 5                 ┆ 2                 ┆ 425              │
# │           ┆ Dark Edition      ┆                   ┆       ┆                   ┆                   ┆                  │
# ...

# %%
# there seems to be a mismatch in datatypes - correcting the datatype
specs_capacity_B = specs_capacity_B.with_columns(pl.col('Bootspace_(litres)').cast(pl.Float64))

# %%
specs_capacity_B['Bootspace_(litres)'].dtype
# Out:
# Float64

# %% [markdown]
# ## COMBINING Dataset A - OVERVIEW AND SPECIFICATIONS

# %%
overview_A_1 = overview_A.clone()
specs_engine_A_1 = specs_engine_A.clone()
specs_dimensions_A_1 = specs_dimensions_A.clone()
specs_capacity_A_1 = specs_capacity_A.clone()

# %%
overview_A_1.shape
# Out:
# (59708, 16)

# %%
specs_engine_A_1.shape
# Out:
# (58635, 10)

# %% [markdown]
# ### combining engine specifications

# %%
# joining Overview and engine specifications
overview_A_1 = overview_A_1.join(specs_engine_A_1,'profileId','left')

# %%
overview_A_1
# Out:
# shape: (59_708, 25)
# ┌───────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ profileId ┆ vehicle      ┆ kilometers ┆ fuelName     ┆ … ┆ Max_Power_(b ┆ Max_Power_at ┆ Max_Torque_( ┆ Max_Torque_a │
# │ ---       ┆ ---          ┆ ---        ┆ ---          ┆   ┆ hp)          ┆ _rpm         ┆ Nm)          ┆ t_rpm        │
# │ str       ┆ str          ┆ f64        ┆ str          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │           ┆              ┆            ┆              ┆   ┆ f64          ┆ str          ┆ f64          ┆ str          │
# ╞═══════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ S2725575  ┆ Mercedes-Ben ┆ 6000.0     ┆ Diesel +     ┆ … ┆ 241.0        ┆  4200 rpm    ┆ 500.0        ┆ 1600-2200    │
# ...

# %%
# there are 2 vehicle columns
# checking which vehicle column to keep

overview_A_1.filter(pl.col('vehicle')!=pl.col('vehicle_right'))
# Out:
# shape: (2, 25)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Power_(bh ┆ Max_Power_at_ ┆ Max_Torque_(N ┆ Max_Torque_a │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ p)            ┆ rpm           ┆ m)            ┆ t_rpm        │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ str           ┆ f64           ┆ str          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D3926753  ┆ Mercedes-Benz ┆ 65000.0    ┆ Petrol   ┆ … ┆ 170.0         ┆ 3700          ┆ 410.0         ┆ 2000         │
# ...

# %%
list(overview_A_1.filter(pl.col('profileId')=='D3926753')['vehicle_right'])
# Out:
# ['Mercedes-Benz C-Class 220 CDI Elegance AT']

# %%
list(overview_A_1.filter(pl.col('profileId')=='D3926753')['vehicle'])
# Out:
# ['Mercedes-Benz C-Class 200 K MT']

# %%
# version name matches the vehicle column 
# removing the vehicle_right column

overview_A_1 = overview_A_1.drop('vehicle_right')

# %% [markdown]
# * there are 2 transmission columns, checking which one is good.

# %%
overview_A_1.filter(pl.col('transmission')!=pl.col('transmission_right'))
# Out:
# shape: (33, 24)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Power_(bh ┆ Max_Power_at_ ┆ Max_Torque_(N ┆ Max_Torque_a │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ p)            ┆ rpm           ┆ m)            ┆ t_rpm        │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ str           ┆ f64           ┆ str          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D3944763  ┆ Kia Sonet HTX ┆ 16000.0    ┆ Petrol   ┆ … ┆ 118.0         ┆  6000 rpm     ┆ 172.0         ┆  1500 rpm    │
# ...

# %%
overview_A_1.filter((pl.col('transmission').is_null()) & (pl.col('transmission_right').is_not_null()))
# Out:
# shape: (0, 24)
# ┌───────────┬─────────┬────────────┬──────────┬───┬─────────────────┬────────────────┬────────────────┬────────────────┐
# │ profileId ┆ vehicle ┆ kilometers ┆ fuelName ┆ … ┆ Max_Power_(bhp) ┆ Max_Power_at_r ┆ Max_Torque_(Nm ┆ Max_Torque_at_ │
# │ ---       ┆ ---     ┆ ---        ┆ ---      ┆   ┆ ---             ┆ pm             ┆ )              ┆ rpm            │
# │ str       ┆ str     ┆ f64        ┆ str      ┆   ┆ f64             ┆ ---            ┆ ---            ┆ ---            │
# │           ┆         ┆            ┆          ┆   ┆                 ┆ str            ┆ f64            ┆ str            │
# ╞═══════════╪═════════╪════════════╪══════════╪═══╪═════════════════╪════════════════╪════════════════╪════════════════╡
# └───────────┴─────────┴────────────┴──────────┴───┴─────────────────┴────────────────┴────────────────┴────────────────┘

# %%
overview_A_1['transmission'].unique()
# Out:
# shape: (3,)
# Series: 'transmission' [str]
# [
# 	null
# 	"Automatic"
# 	"Manual"
# ]

# %%
overview_A_1['transmission_right'].unique()
# Out:
# shape: (3,)
# Series: 'transmission_right' [str]
# [
# 	"Manual"
# 	"Automatic"
# 	null
# ]

# %%
overview_A_1.filter(overview_A_1['transmission'].is_null())
# Out:
# shape: (6, 24)
# ┌───────────┬───────────────┬────────────┬───────────┬───┬───────────────┬───────────────┬──────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName  ┆ … ┆ Max_Power_(bh ┆ Max_Power_at_ ┆ Max_Torque_( ┆ Max_Torque_a │
# │ ---       ┆ ---           ┆ ---        ┆ ---       ┆   ┆ p)            ┆ rpm           ┆ Nm)          ┆ t_rpm        │
# │ str       ┆ str           ┆ f64        ┆ str       ┆   ┆ ---           ┆ ---           ┆ ---          ┆ ---          │
# │           ┆               ┆            ┆           ┆   ┆ f64           ┆ str           ┆ f64          ┆ str          │
# ╞═══════════╪═══════════════╪════════════╪═══════════╪═══╪═══════════════╪═══════════════╪══════════════╪══════════════╡
# │ D4178113  ┆ BMW Z4        ┆ 11000.0    ┆ Not       ┆ … ┆ null          ┆ null          ┆ null         ┆ null         │
# ...

# %% [markdown]
# * both transmission columns are null
# * but, it can be seen that where the transmission_right is null we have transmission value.
# * removing transmission_right and keeping transmission column

# %%
overview_A_1.filter(overview_A_1['transmission_right'].is_null())
# Out:
# shape: (1_073, 24)
# ┌───────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ profileId ┆ vehicle      ┆ kilometers ┆ fuelName     ┆ … ┆ Max_Power_(b ┆ Max_Power_at ┆ Max_Torque_( ┆ Max_Torque_a │
# │ ---       ┆ ---          ┆ ---        ┆ ---          ┆   ┆ hp)          ┆ _rpm         ┆ Nm)          ┆ t_rpm        │
# │ str       ┆ str          ┆ f64        ┆ str          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │           ┆              ┆            ┆              ┆   ┆ f64          ┆ str          ┆ f64          ┆ str          │
# ╞═══════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ S2733827  ┆ Maruti       ┆ 100000.0   ┆ Petrol       ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# ...

# %%
overview_A_1 = overview_A_1.drop('transmission_right')

# %%
overview_A_1
# Out:
# shape: (59_708, 23)
# ┌───────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ profileId ┆ vehicle      ┆ kilometers ┆ fuelName     ┆ … ┆ Max_Power_(b ┆ Max_Power_at ┆ Max_Torque_( ┆ Max_Torque_a │
# │ ---       ┆ ---          ┆ ---        ┆ ---          ┆   ┆ hp)          ┆ _rpm         ┆ Nm)          ┆ t_rpm        │
# │ str       ┆ str          ┆ f64        ┆ str          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │           ┆              ┆            ┆              ┆   ┆ f64          ┆ str          ┆ f64          ┆ str          │
# ╞═══════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ S2725575  ┆ Mercedes-Ben ┆ 6000.0     ┆ Diesel +     ┆ … ┆ 241.0        ┆  4200 rpm    ┆ 500.0        ┆ 1600-2200    │
# ...

# %% [markdown]
# * there are 2 fuel columns now fuelName and Fuel
# * Checking both the coulums

# %%
overview_A_1['Fuel'].unique()
# Out:
# shape: (8,)
# Series: 'Fuel' [str]
# [
# 	null
# 	"LPG"
# 	"CNG"
# 	"Hybrid (Electr…
# 	"Diesel"
# 	"Petrol"
# 	"Electric"
# 	"Hybrid (Electr…
# ]

# %%
# checking if null value in the Fuel column could be compensated with fuelName
overview_A_1.filter(overview_A_1['Fuel'].is_null())
# Out:
# shape: (1_073, 23)
# ┌───────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ profileId ┆ vehicle      ┆ kilometers ┆ fuelName     ┆ … ┆ Max_Power_(b ┆ Max_Power_at ┆ Max_Torque_( ┆ Max_Torque_a │
# │ ---       ┆ ---          ┆ ---        ┆ ---          ┆   ┆ hp)          ┆ _rpm         ┆ Nm)          ┆ t_rpm        │
# │ str       ┆ str          ┆ f64        ┆ str          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │           ┆              ┆            ┆              ┆   ┆ f64          ┆ str          ┆ f64          ┆ str          │
# ╞═══════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ S2733827  ┆ Maruti       ┆ 100000.0   ┆ Petrol       ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# ...

# %% [markdown]
# * so, the fuelName values could be compensated for the null values in the Fuel
# *  splitting the fuelName and getting the actual fuel value

# %%
# splitting the fuelName column value and storing the new values in compFuel
overview_A_1 = overview_A_1.with_columns(pl.col('fuelName').str.split(' ').list[0].alias('compFuel'))

# %%
# checking unique fuel values in fuelName
overview_A_1.filter(overview_A_1['Fuel'].is_null())['compFuel'].unique()
# Out:
# shape: (5,)
# Series: 'compFuel' [str]
# [
# 	"Not"
# 	"CNG"
# 	"LPG"
# 	"Diesel"
# 	"Petrol"
# ]

# %%
# replacing "Not" with null value 
overview_A_1 = overview_A_1.with_columns(pl.col('compFuel').str.replace('Not',np.nan))

# %%
# creating a new column "newFuel" and inserting values with a condition 

overview_A_1 = overview_A_1.with_columns(pl.when(pl.col('Fuel').is_null()).then(pl.col('compFuel')).otherwise(pl.col('Fuel')).alias('newFuel'))

# %%
# checking if the Fuel and newFuel values are same after modification.
overview_A_1.filter(pl.col('Fuel') == pl.col("newFuel"))
# Out:
# shape: (58_635, 25)
# ┌───────────┬─────────────────┬────────────┬────────────────┬───┬────────────────┬────────────────┬──────────┬─────────┐
# │ profileId ┆ vehicle         ┆ kilometers ┆ fuelName       ┆ … ┆ Max_Torque_(Nm ┆ Max_Torque_at_ ┆ compFuel ┆ newFuel │
# │ ---       ┆ ---             ┆ ---        ┆ ---            ┆   ┆ )              ┆ rpm            ┆ ---      ┆ ---     │
# │ str       ┆ str             ┆ f64        ┆ str            ┆   ┆ ---            ┆ ---            ┆ str      ┆ str     │
# │           ┆                 ┆            ┆                ┆   ┆ f64            ┆ str            ┆          ┆         │
# ╞═══════════╪═════════════════╪════════════╪════════════════╪═══╪════════════════╪════════════════╪══════════╪═════════╡
# │ S2725575  ┆ Mercedes-Benz   ┆ 6000.0     ┆ Diesel +       ┆ … ┆ 500.0          ┆  1600-2200 rpm ┆ Diesel   ┆ Diesel  │
# ...

# %%
overview_A_1.filter(pl.col('Fuel').is_null())
# Out:
# shape: (1_073, 25)
# ┌───────────┬─────────────────┬────────────┬────────────────┬───┬────────────────┬────────────────┬──────────┬─────────┐
# │ profileId ┆ vehicle         ┆ kilometers ┆ fuelName       ┆ … ┆ Max_Torque_(Nm ┆ Max_Torque_at_ ┆ compFuel ┆ newFuel │
# │ ---       ┆ ---             ┆ ---        ┆ ---            ┆   ┆ )              ┆ rpm            ┆ ---      ┆ ---     │
# │ str       ┆ str             ┆ f64        ┆ str            ┆   ┆ ---            ┆ ---            ┆ str      ┆ str     │
# │           ┆                 ┆            ┆                ┆   ┆ f64            ┆ str            ┆          ┆         │
# ╞═══════════╪═════════════════╪════════════╪════════════════╪═══╪════════════════╪════════════════╪══════════╪═════════╡
# │ S2733827  ┆ Maruti Suzuki   ┆ 100000.0   ┆ Petrol         ┆ … ┆ null           ┆ null           ┆ Petrol   ┆ Petrol  │
# ...

# %%
str(np.nan)
# Out:
# 'nan'

# %%
list(overview_A_1['newFuel'].unique())
# Out:
# ['Hybrid (Electric + Diesel)',
#  'Hybrid (Electric + Petrol)',
#  'CNG',
#  'NaN',
#  'Electric',
#  'Diesel',
#  'Petrol',
#  'LPG']

# %%
overview_A_1.group_by('newFuel').count()
# Out:
# shape: (8, 2)
# ┌────────────────────────────┬───────┐
# │ newFuel                    ┆ count │
# │ ---                        ┆ ---   │
# │ str                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ Petrol                     ┆ 32167 │
# │ Hybrid (Electric + Petrol) ┆ 140   │
# │ Diesel                     ┆ 25081 │
# │ CNG                        ┆ 1815  │
# │ NaN                        ┆ 6     │
# │ LPG                        ┆ 259   │
# │ Electric                   ┆ 239   │
# │ Hybrid (Electric + Diesel) ┆ 1     │
# └────────────────────────────┴───────┘

# %% [markdown]
# * 6 nan values were found.
# * this is fine for now.
# * deleting other fuel columns from the dataframe

# %%
overview_A_1 = overview_A_1.drop(['Fuel','compFuel','fuelName'])

# %%
overview_A_1 = overview_A_1.rename({'newFuel':'Fuel'})

# %%
#final dataset
overview_A_1.head()
# Out:
# shape: (5, 22)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Max_Power_at_ ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Fuel   │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ rpm           ┆ m)            ┆ _rpm          ┆ ---    │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ ---           ┆ ---           ┆ ---           ┆ str    │
# │           ┆                ┆            ┆               ┆   ┆ str           ┆ f64           ┆ str           ┆        │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪════════╡
# │ S2725575  ┆ Mercedes-Benz  ┆ 6000.0     ┆ Third Party   ┆ … ┆  4200 rpm     ┆ 500.0         ┆ 1600-2200 rpm ┆ Diesel │
# ...

# %% [markdown]
# ### combining dimensions

# %%
# joining Overview and engine specifications
overview_A_1 = overview_A_1.join(specs_dimensions_A_1,'profileId','left')

# %%
overview_A_1.shape
# Out:
# (59708, 29)

# %%
overview_A_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Fuel',
#  'vehicle_right',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)']

# %% [markdown]
# * vehicle_right is an extra column and can be removed

# %%
overview_A_1 = overview_A_1.drop('vehicle_right')

# %%
overview_A_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Fuel',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)']

# %% [markdown]
# ### combining capcity

# %%
overview_A_1 = overview_A_1.join(specs_capacity_A_1,'profileId','left')

# %%
overview_A_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Fuel',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)',
#  'vehicle_right',
#  'Bootspace_(litres)',
#  'Doors',
#  'Fuel_Tank_Capacity_(litres)',
#  'Seating_Rows_(rows)',
#  'Seating_Capacity_(persons)']

# %% [markdown]
# * vehicle_right here too is an extra column and can be removed

# %%
overview_A_1 = overview_A_1.drop('vehicle_right')

# %%
overview_A_1.head()
# Out:
# shape: (5, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────┬────────────────┬───────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Doors ┆ Fuel_Tank_Capa ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ ---   ┆ city_(litres)  ┆ (rows)        ┆ ity_(persons) │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ i64   ┆ ---            ┆ ---           ┆ ---           │
# │           ┆                ┆            ┆               ┆   ┆       ┆ f64            ┆ i64           ┆ i64           │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════╪════════════════╪═══════════════╪═══════════════╡
# │ S2725575  ┆ Mercedes-Benz  ┆ 6000.0     ┆ Third Party   ┆ … ┆ 5     ┆ 93.0           ┆ 2             ┆ 5             │
# ...

# %%
overview_A_1.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %% [markdown]
# ## COMBINING Dataset B - OVERVIEW AND SPECIFICATIONS

# %%
overview_B_1 = overview_B.clone()
specs_engine_B_1 = specs_engine_B.clone()
specs_dimensions_B_1 = specs_dimensions_B.clone()
specs_capacity_B_1 = specs_capacity_B.clone()

# %%
overview_B_1.shape
# Out:
# (30274, 16)

# %%
specs_engine_B_1.shape
# Out:
# (30323, 10)

# %% [markdown]
# ### combining engine specifications

# %%
# joining Overview and engine specifications
overview_B_1 = overview_B_1.join(specs_engine_B_1,'profileId','left')

# %%
overview_B_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'fuelName',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'vehicle_right',
#  'Mileage (ARAI)',
#  'Fuel',
#  'transmission_right',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm']

# %%
overview_B_1
# Out:
# shape: (30_274, 25)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ m)            ┆ _rpm          ┆ p)            ┆ _rpm         │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ f64           ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D4135089  ┆ Tata Harrier  ┆ 39420.0    ┆ Diesel   ┆ … ┆ 350.0         ┆ 1750.0        ┆ 168.0         ┆ 3750.0       │
# ...

# %%
# there are 2 vehicle columns
# checking which vehicle column to keep

overview_B_1.filter(pl.col('vehicle')!=pl.col('vehicle_right'))
# Out:
# shape: (0, 25)
# ┌───────────┬─────────┬────────────┬──────────┬───┬─────────────────┬────────────────┬────────────────┬────────────────┐
# │ profileId ┆ vehicle ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(Nm) ┆ Max_Torque_at_ ┆ Max_Power_(bhp ┆ Max_Power_at_r │
# │ ---       ┆ ---     ┆ ---        ┆ ---      ┆   ┆ ---             ┆ rpm            ┆ )              ┆ pm             │
# │ str       ┆ str     ┆ f64        ┆ str      ┆   ┆ f64             ┆ ---            ┆ ---            ┆ ---            │
# │           ┆         ┆            ┆          ┆   ┆                 ┆ f64            ┆ f64            ┆ f64            │
# ╞═══════════╪═════════╪════════════╪══════════╪═══╪═════════════════╪════════════════╪════════════════╪════════════════╡
# └───────────┴─────────┴────────────┴──────────┴───┴─────────────────┴────────────────┴────────────────┴────────────────┘

# %%
# version name matches the vehicle column 
# removing the vehicle_right column

overview_B_1 = overview_B_1.drop('vehicle_right')

# %%
overview_B_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'fuelName',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Fuel',
#  'transmission_right',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm']

# %% [markdown]
# * there are 2 transmission columns, checking which one is good.

# %%
overview_B_1.filter(pl.col('transmission')!=pl.col('transmission_right'))
# Out:
# shape: (35, 24)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ m)            ┆ _rpm          ┆ p)            ┆ _rpm         │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ f64           ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D4149015  ┆ Hyundai Venue ┆ 33764.0    ┆ Petrol   ┆ … ┆ 172.0         ┆ 1500.0        ┆ 118.0         ┆ 6000.0       │
# ...

# %%
overview_B_1.filter((pl.col('transmission').is_null()) & (pl.col('transmission_right').is_not_null()))
# Out:
# shape: (0, 24)
# ┌───────────┬─────────┬────────────┬──────────┬───┬─────────────────┬────────────────┬────────────────┬────────────────┐
# │ profileId ┆ vehicle ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(Nm) ┆ Max_Torque_at_ ┆ Max_Power_(bhp ┆ Max_Power_at_r │
# │ ---       ┆ ---     ┆ ---        ┆ ---      ┆   ┆ ---             ┆ rpm            ┆ )              ┆ pm             │
# │ str       ┆ str     ┆ f64        ┆ str      ┆   ┆ f64             ┆ ---            ┆ ---            ┆ ---            │
# │           ┆         ┆            ┆          ┆   ┆                 ┆ f64            ┆ f64            ┆ f64            │
# ╞═══════════╪═════════╪════════════╪══════════╪═══╪═════════════════╪════════════════╪════════════════╪════════════════╡
# └───────────┴─────────┴────────────┴──────────┴───┴─────────────────┴────────────────┴────────────────┴────────────────┘

# %%
overview_B_1['transmission'].unique()
# Out:
# shape: (2,)
# Series: 'transmission' [str]
# [
# 	"Manual"
# 	"Automatic"
# ]

# %%
overview_B_1['transmission_right'].unique()
# Out:
# shape: (3,)
# Series: 'transmission_right' [str]
# [
# 	null
# 	"Manual"
# 	"Automatic"
# ]

# %%
overview_B_1.filter(overview_B_1['transmission_right'].is_null())
# Out:
# shape: (588, 24)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ m)            ┆ _rpm          ┆ p)            ┆ _rpm         │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ f64           ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D4060177  ┆ Honda Brio V  ┆ 89000.0    ┆ Petrol   ┆ … ┆ null          ┆ null          ┆ null          ┆ null         │
# ...

# %% [markdown]
# * the transmission_right has null values hence removing transmission_right and keeping transmission column

# %%
overview_B_1 = overview_B_1.drop('transmission_right')

# %%
overview_B_1
# Out:
# shape: (30_274, 23)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ m)            ┆ _rpm          ┆ p)            ┆ _rpm         │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ f64           ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D4135089  ┆ Tata Harrier  ┆ 39420.0    ┆ Diesel   ┆ … ┆ 350.0         ┆ 1750.0        ┆ 168.0         ┆ 3750.0       │
# ...

# %% [markdown]
# * there are 2 fuel columns now fuelName and Fuel
# * Checking both the coulums

# %%
overview_B_1['Fuel'].unique()
# Out:
# shape: (7,)
# Series: 'Fuel' [str]
# [
# 	"Electric"
# 	"Diesel"
# 	"LPG"
# 	null
# 	"CNG"
# 	"Petrol"
# 	"Hybrid (Electr…
# ]

# %%
# checking if null value in the Fuel column could be compensated with fuelName
overview_B_1.filter(overview_B_1['Fuel'].is_null())
# Out:
# shape: (588, 23)
# ┌───────────┬───────────────┬────────────┬──────────┬───┬───────────────┬───────────────┬───────────────┬──────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ fuelName ┆ … ┆ Max_Torque_(N ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at │
# │ ---       ┆ ---           ┆ ---        ┆ ---      ┆   ┆ m)            ┆ _rpm          ┆ p)            ┆ _rpm         │
# │ str       ┆ str           ┆ f64        ┆ str      ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆          ┆   ┆ f64           ┆ f64           ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪══════════════╡
# │ D4060177  ┆ Honda Brio V  ┆ 89000.0    ┆ Petrol   ┆ … ┆ null          ┆ null          ┆ null          ┆ null         │
# ...

# %% [markdown]
# * so, the fuelName values could be compensated for the null values in the Fuel
# *  splitting the fuelName and getting the actual fuel value

# %%
# splitting the fuelName column value and storing the new values in compFuel
overview_B_1 = overview_B_1.with_columns(pl.col('fuelName').str.split(' ').list[0].alias('compFuel'))

# %%
# checking unique fuel values in fuelName
overview_B_1.filter(overview_B_1['Fuel'].is_null())['compFuel'].unique()
# Out:
# shape: (4,)
# Series: 'compFuel' [str]
# [
# 	"CNG"
# 	"LPG"
# 	"Diesel"
# 	"Petrol"
# ]

# %%
# creating a new column "newFuel" and inserting values with a condition 

overview_B_1 = overview_B_1.with_columns(pl.when(pl.col('Fuel').is_null()).then(pl.col('compFuel')).otherwise(pl.col('Fuel')).alias('newFuel'))

# %%
# checking if the Fuel and newFuel values are same after modification.
overview_B_1.filter(pl.col('Fuel') == pl.col("newFuel"))
# Out:
# shape: (29_686, 25)
# ┌───────────┬────────────────────┬────────────┬──────────┬───┬─────────────────┬──────────────────┬──────────┬─────────┐
# │ profileId ┆ vehicle            ┆ kilometers ┆ fuelName ┆ … ┆ Max_Power_(bhp) ┆ Max_Power_at_rpm ┆ compFuel ┆ newFuel │
# │ ---       ┆ ---                ┆ ---        ┆ ---      ┆   ┆ ---             ┆ ---              ┆ ---      ┆ ---     │
# │ str       ┆ str                ┆ f64        ┆ str      ┆   ┆ f64             ┆ f64              ┆ str      ┆ str     │
# ╞═══════════╪════════════════════╪════════════╪══════════╪═══╪═════════════════╪══════════════════╪══════════╪═════════╡
# │ D4135089  ┆ Tata Harrier XZ    ┆ 39420.0    ┆ Diesel   ┆ … ┆ 168.0           ┆ 3750.0           ┆ Diesel   ┆ Diesel  │
# │           ┆ Dark Edition       ┆            ┆          ┆   ┆                 ┆                  ┆          ┆         │
# ...

# %%
overview_B_1.filter(pl.col('Fuel').is_null())
# Out:
# shape: (588, 25)
# ┌───────────┬───────────────────┬────────────┬──────────┬───┬──────────────────┬──────────────────┬──────────┬─────────┐
# │ profileId ┆ vehicle           ┆ kilometers ┆ fuelName ┆ … ┆ Max_Power_(bhp)  ┆ Max_Power_at_rpm ┆ compFuel ┆ newFuel │
# │ ---       ┆ ---               ┆ ---        ┆ ---      ┆   ┆ ---              ┆ ---              ┆ ---      ┆ ---     │
# │ str       ┆ str               ┆ f64        ┆ str      ┆   ┆ f64              ┆ f64              ┆ str      ┆ str     │
# ╞═══════════╪═══════════════════╪════════════╪══════════╪═══╪══════════════════╪══════════════════╪══════════╪═════════╡
# │ D4060177  ┆ Honda Brio V MT   ┆ 89000.0    ┆ Petrol   ┆ … ┆ null             ┆ null             ┆ Petrol   ┆ Petrol  │
# │ D4101181  ┆ BMW 3 Series 320d ┆ 49366.0    ┆ Diesel   ┆ … ┆ null             ┆ null             ┆ Diesel   ┆ Diesel  │
# ...

# %%
list(overview_B_1['newFuel'].unique())
# Out:
# ['LPG', 'Electric', 'CNG', 'Hybrid (Electric + Petrol)', 'Petrol', 'Diesel']

# %%
overview_B_1.group_by('newFuel').count()
# Out:
# shape: (6, 2)
# ┌────────────────────────────┬───────┐
# │ newFuel                    ┆ count │
# │ ---                        ┆ ---   │
# │ str                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ Hybrid (Electric + Petrol) ┆ 88    │
# │ Petrol                     ┆ 16931 │
# │ LPG                        ┆ 40    │
# │ Electric                   ┆ 193   │
# │ Diesel                     ┆ 12260 │
# │ CNG                        ┆ 762   │
# └────────────────────────────┴───────┘

# %% [markdown]
# * no nan values were found.
# * deleting other fuel columns from the dataframe

# %%
overview_B_1 = overview_B_1.drop(['Fuel','compFuel','fuelName'])

# %%
overview_B_1 = overview_B_1.rename({'newFuel':'Fuel'})

# %%
#final dataset
overview_B_1.head()
# Out:
# shape: (5, 22)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Max_Torque_at ┆ Max_Power_(bh ┆ Max_Power_at_ ┆ Fuel   │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ _rpm          ┆ p)            ┆ rpm           ┆ ---    │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ ---           ┆ ---           ┆ ---           ┆ str    │
# │           ┆                ┆            ┆               ┆   ┆ f64           ┆ f64           ┆ f64           ┆        │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪════════╡
# │ D4135089  ┆ Tata Harrier   ┆ 39420.0    ┆ Comprehensive ┆ … ┆ 1750.0        ┆ 168.0         ┆ 3750.0        ┆ Diesel │
# ...

# %% [markdown]
# ### combining dimensions

# %%
# joining Overview and engine specifications
overview_B_1 = overview_B_1.join(specs_dimensions_B_1,'profileId','left')

# %%
overview_B_1.shape
# Out:
# (30274, 29)

# %%
overview_B_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Fuel',
#  'vehicle_right',
#  'Length_(mm)',
#  'Width_(mm)',
#  'Kerb_Weight_(mm)',
#  'Wheelbase_(mm)',
#  'Height_(mm)',
#  'Ground_Clearance_(mm)']

# %% [markdown]
# * vehicle_right is an extra column and can be removed

# %%
overview_B_1 = overview_B_1.drop('vehicle_right')

# %%
overview_B_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Fuel',
#  'Length_(mm)',
#  'Width_(mm)',
#  'Kerb_Weight_(mm)',
#  'Wheelbase_(mm)',
#  'Height_(mm)',
#  'Ground_Clearance_(mm)']

# %% [markdown]
# ### combining capcity

# %%
overview_B_1 = overview_B_1.join(specs_capacity_B_1,'profileId','left')

# %%
overview_B_1.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Fuel',
#  'Length_(mm)',
#  'Width_(mm)',
#  'Kerb_Weight_(mm)',
#  'Wheelbase_(mm)',
#  'Height_(mm)',
#  'Ground_Clearance_(mm)',
#  'vehicle_right',
#  'Fuel_Tank_Capacity_(litres)',
#  'Doors',
#  'Seating_Capacity_(persons)',
#  'Seating_Rows_(rows)',
#  'Bootspace_(litres)']

# %% [markdown]
# * vehicle_right here too is an extra column and can be removed

# %%
overview_B_1 = overview_B_1.drop('vehicle_right')

# %%
overview_B_1.head()
# Out:
# shape: (5, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────┬────────────────┬───────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Doors ┆ Seating_Capaci ┆ Seating_Rows_ ┆ Bootspace_(li │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ ---   ┆ ty_(persons)   ┆ (rows)        ┆ tres)         │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ i64   ┆ ---            ┆ ---           ┆ ---           │
# │           ┆                ┆            ┆               ┆   ┆       ┆ i64            ┆ i64           ┆ i64           │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════╪════════════════╪═══════════════╪═══════════════╡
# │ D4135089  ┆ Tata Harrier   ┆ 39420.0    ┆ Comprehensive ┆ … ┆ 5     ┆ 5              ┆ 2             ┆ 425           │
# ...

# %%
overview_B_1.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Seating_Capac ┆ Seating_Rows_ ┆ Bootspace_(li │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ ity_(persons) ┆ (rows)        ┆ tres)         │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ ---           ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆ f64           ┆ f64           │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# │ count      ┆ 30274     ┆ 30274         ┆ 30274.0      ┆ … ┆ 30274.0  ┆ 30274.0       ┆ 30274.0       ┆ 30274.0       │
# ...

# %% [markdown]
# ## UNION OF Datasets A and B

# %% [markdown]
# * Before combining datasets A and B, duplicates should be handled
# * There could duplicate profileIds between Dataset A and Dataset B
# * Checking duplicates

# %% [markdown]
# ### REMOVING DUPLICATES

# %%
overview_duplicates = overview_A_1.join(overview_B_1,'profileId','inner')

# %%
overview_duplicates.shape
# Out:
# (13620, 65)

# %% [markdown]
# * there are 13_620 duplicate records
# * checking if the column values are the same

# %%
overview_duplicates.head()
# Out:
# shape: (5, 65)
# ┌───────────┬───────────────┬────────────┬───────────┬───┬─────────────┬───────────────┬───────────────┬───────────────┐
# │ profileId ┆ vehicle       ┆ kilometers ┆ insurance ┆ … ┆ Doors_right ┆ Seating_Capac ┆ Seating_Rows_ ┆ Bootspace_(li │
# │ ---       ┆ ---           ┆ ---        ┆ ---       ┆   ┆ ---         ┆ ity_(persons) ┆ (rows)_right  ┆ tres)_right   │
# │ str       ┆ str           ┆ f64        ┆ str       ┆   ┆ i64         ┆ _right        ┆ ---           ┆ ---           │
# │           ┆               ┆            ┆           ┆   ┆             ┆ ---           ┆ i64           ┆ i64           │
# │           ┆               ┆            ┆           ┆   ┆             ┆ i64           ┆               ┆               │
# ╞═══════════╪═══════════════╪════════════╪═══════════╪═══╪═════════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %%
overview_duplicates.describe()[:,0:34]
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %%
overview_duplicates.describe()[:,34:67]
# Out:
# shape: (9, 32)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ vehicle_righ ┆ kilometers_r ┆ insurance_ri ┆ makeName_ri ┆ … ┆ Doors_right ┆ Seating_Cap ┆ Seating_Row ┆ Bootspace_( │
# │ t            ┆ ight         ┆ ght          ┆ ght         ┆   ┆ ---         ┆ acity_(pers ┆ s_(rows)_ri ┆ litres)_rig │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ f64         ┆ ons)_right  ┆ ght         ┆ ht          │
# │ str          ┆ f64          ┆ str          ┆ str         ┆   ┆             ┆ ---         ┆ ---         ┆ ---         │
# │              ┆              ┆              ┆             ┆   ┆             ┆ f64         ┆ f64         ┆ f64         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# ...

# %% [markdown]
# * comparing the duplicates, there are more or less similar level of null values within the duplicate records of datasets A and B
# * comparing some of  values of the duplicates below

# %%
right_col = []
for i in overview_A_1.columns:
    right_col.append(i + '_right')

# %%
right_col
# Out:
# ['profileId_right',
#  'vehicle_right',
#  'kilometers_right',
#  'insurance_right',
#  'makeName_right',
#  'versionName_right',
#  'makeYear_right',
#  'makeMonth_right',
#  'city_right',
#  'noOfOwners_right',
#  'regType_right',
#  'price_right',
#  'modelName_right',
#  'state_right',
#  'transmission_right',
#  'Mileage (ARAI)_right',
#  'Displacement_(cc)_right',
#  'Max_Power_(bhp)_right',
#  'Max_Power_at_rpm_right',
#  'Max_Torque_(Nm)_right',
#  'Max_Torque_at_rpm_right',
#  'Fuel_right',
#  'Ground_Clearance_(mm)_right',
#  'Height_(mm)_right',
#  'Kerb_Weight_(mm)_right',
#  'Length_(mm)_right',
#  'Wheelbase_(mm)_right',
#  'Width_(mm)_right',
#  'Bootspace_(litres)_right',
#  'Doors_right',
#  'Fuel_Tank_Capacity_(litres)_right',
#  'Seating_Rows_(rows)_right',
#  'Seating_Capacity_(persons)_right']

# %%
list(overview_duplicates.filter(pl.col('vehicle') != pl.col('vehicle_right'))['vehicle'])
# Out:
# ['Mahindra Thar LX Hard Top Petrol AT',
#  'Maruti Suzuki Ertiga VDi 1.5 Diesel',
#  'Volkswagen Polo Highline Plus 1.0 (P) 16 Alloy',
#  'Jeep Compass Limited Plus 2.0 Diesel 4x4 AT',
#  'Mercedes-Benz S-Class 500',
#  'Maruti Suzuki Swift VXi',
#  'Skoda Superb Style TSI AT',
#  'Maruti Suzuki Celerio VXi AMT',
#  'Volkswagen Vento Highline Petrol AT [2015-2016]',
#  'Hyundai Creta 1.6 SX Plus',
#  'Audi A3 35 TDI Premium Plus + Sunroof',
#  'Jeep Compass Limited 2.0 Diesel 4x4 [2017-2020]',
#  'Mahindra XUV300 W8 (O) 1.2 Petrol AMT',
#  'Honda All New City V CVT Petrol',
#  'Honda City 4th Generation V Petrol [2017-2019]',
#  'Mercedes-Benz C-Class C 220 CDI Avantgarde',
#  'BMW 5 Series 525i Sedan',
#  'Jeep Compass Limited 2.0 Diesel [2017-2020]',
#  'Mercedes-Benz GLC 200 Progressive',
#  'Kia Seltos HTX 1.5 Diesel',
#  'Audi Q5 30 TDI Premium Edition',
#  'Hyundai Grand i10 Sportz (O) 1.2 Kappa VTVT [2017-2018]',
#  'Audi A3 35 TDI Premium + Sunroof',
# ...

# %%
list(overview_duplicates.filter(pl.col('vehicle') != pl.col('vehicle_right'))['vehicle_right'])
# Out:
# ['Mahindra Thar LX Hard Top Petrol MT',
#  'Maruti Suzuki Ertiga VDi 1.3 Diesel',
#  'Volkswagen Polo Highline Plus 1.2( P)16 Alloy [2017-2018]',
#  'Jeep Compass Limited Plus Diesel 4x4',
#  'Mercedes-Benz SLK-Class SLK 350',
#  'Maruti Suzuki Swift ZXi',
#  'Skoda Superb L&K TSI AT',
#  'Maruti Suzuki Celerio VXi AMT ABS',
#  'Volkswagen Vento Highline Plus 1.2 (P) AT 16 Alloy',
#  'Hyundai Creta SX Plus 1.6 CRDI Dual Tone',
#  'Audi A3 35 TDI Attraction',
#  'Jeep Compass Limited 2.0 Diesel [2017-2020]',
#  'Mahindra XUV300 W8 (O) 1.2 Petrol',
#  'Honda City 4th Generation V CVT Petrol',
#  'Honda City V Petrol [2017-2019]',
#  'Mercedes-Benz C-Class C 200 Avantgarde',
#  'BMW 5 Series 530i Sedan',
#  'Jeep Compass Limited 2.0 Diesel 4x4 [2017-2020]',
#  'Mercedes-Benz GLC 300 Progressive',
#  'Kia Seltos 2022 HTX 1.5 Diesel',
#  'Audi Q5 30 TDI Sports Edition',
#  'Hyundai Grand i10 Sportz 1.2 Kappa VTVT [2016-2017]',
#  'Audi A3 35 TDI Premium Plus + Sunroof',
# ...

# %%
overview_duplicates.filter(pl.col('price') != pl.col('price_right'))[['price','price_right']]
# Out:
# shape: (1_384, 2)
# ┌─────────┬─────────────┐
# │ price   ┆ price_right │
# │ ---     ┆ ---         │
# │ i64     ┆ i64         │
# ╞═════════╪═════════════╡
# │ 2849999 ┆ 2799999     │
# │ 270000  ┆ 299000      │
# │ 245000  ┆ 255000      │
# │ 445000  ┆ 375000      │
# │ …       ┆ …           │
# │ 2400000 ┆ 2500000     │
# │ 1590000 ┆ 1645000     │
# │ 2850000 ┆ 2970000     │
# │ 650000  ┆ 670000      │
# └─────────┴─────────────┘

# %% [markdown]
# * Some of the duplicate values have different prices as well, so, it is better to go with the latest data.
# * based on the date of extration the left dataframe, i.e. **dataset A** has the latest values.
# * So, it is better to remove the duplicates from the right dataframe, i.e. from **dataset B**

# %%
duplicate_profileIds = list(overview_duplicates['profileId'].unique())

# %%
len(duplicate_profileIds)
# Out:
# 13620

# %%
overview_B_1.shape
# Out:
# (30274, 33)

# %%
# selecting data other than duplicate

overview_B_1.filter(pl.col('profileId').is_in(duplicate_profileIds).not_())
# Out:
# shape: (16_654, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────┬────────────────┬───────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Doors ┆ Seating_Capaci ┆ Seating_Rows_ ┆ Bootspace_(li │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ ---   ┆ ty_(persons)   ┆ (rows)        ┆ tres)         │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ i64   ┆ ---            ┆ ---           ┆ ---           │
# │           ┆                ┆            ┆               ┆   ┆       ┆ i64            ┆ i64           ┆ i64           │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════╪════════════════╪═══════════════╪═══════════════╡
# │ D4087571  ┆ Jeep Compass   ┆ 65000.0    ┆ Comprehensive ┆ … ┆ 5     ┆ 5              ┆ 2             ┆ 438           │
# ...

# %%
# checking if the selection of unique values is correct by tallying the total selection with the overview main data

overview_B_1.filter(pl.col('profileId').is_in(duplicate_profileIds)).shape[0] + overview_B_1.filter(pl.col('profileId').is_in(duplicate_profileIds).not_()).shape[0]
# Out:
# 30274

# %%
# finalizing the selection of non-duplicate values

overview_B_1 = overview_B_1.filter(pl.col('profileId').is_in(duplicate_profileIds).not_())

# %%
overview_B_1.shape
# Out:
# (16654, 33)

# %%
print x
# Out:
#   Cell In[135], line 1
#     print x
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# ### COMBINING dataset A and B

# %%
# cloning datasets before combining

overview_A_2 = overview_A_1.clone()
overview_B_2 = overview_B_1.clone()

# %% [markdown]
# overview_A_2 = overview_A_2.with_columns(pl.col('Max_Power_at_rpm').str.strip_chars().str.slice(0,4).replace({'':0}).cast(pl.Float64),
#                           pl.col('Max_Torque_at_rpm').str.strip_chars().str.slice(0,4).str.strip_chars().replace({'':0}).cast(pl.Float64)
#                          )

# %% [markdown]
# #there seems to be a mismatch in datatypes - correcting the datatype
# overview_B_2 = overview_B_2.with_columns(pl.col('Bootspace_(litres)').cast(pl.Float64))

# %%
overview_A_2.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Fuel',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)',
#  'Bootspace_(litres)',
#  'Doors',
#  'Fuel_Tank_Capacity_(litres)',
#  'Seating_Rows_(rows)',
#  'Seating_Capacity_(persons)']

# %%
overview_B_2.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Fuel',
#  'Length_(mm)',
#  'Width_(mm)',
#  'Kerb_Weight_(mm)',
#  'Wheelbase_(mm)',
#  'Height_(mm)',
#  'Ground_Clearance_(mm)',
#  'Fuel_Tank_Capacity_(litres)',
#  'Doors',
#  'Seating_Capacity_(persons)',
#  'Seating_Rows_(rows)',
#  'Bootspace_(litres)']

# %%
# reordering columns for combining

overview_B_2 = overview_B_2.select(pl.col(
                                            'profileId',
                                             'vehicle',
                                             'kilometers',
                                             'insurance',
                                             'makeName',
                                             'versionName',
                                             'makeYear',
                                             'makeMonth',
                                             'city',
                                             'noOfOwners',
                                             'regType',
                                             'price',
                                             'modelName',
                                             'state',
                                             'transmission',
                                             'Mileage (ARAI)',
                                             'Displacement_(cc)',
                                             'Max_Power_(bhp)',
                                             'Max_Power_at_rpm',
                                             'Max_Torque_(Nm)',
                                             'Max_Torque_at_rpm',
                                             'Fuel',
                                             'Ground_Clearance_(mm)',
                                             'Height_(mm)',
                                             'Kerb_Weight_(mm)',
                                             'Length_(mm)',
                                             'Wheelbase_(mm)',
                                             'Width_(mm)',
                                             'Bootspace_(litres)',
                                             'Doors',
                                             'Fuel_Tank_Capacity_(litres)',
                                             'Seating_Rows_(rows)',
                                             'Seating_Capacity_(persons)'
                                        ))

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %%
overview_B_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %% [markdown]
# overview_B_2["Bootspace_(litres)"].dtype

# %%
overview_A_2.shape
# Out:
# (59708, 33)

# %%
overview_B_2.shape
# Out:
# (16654, 33)

# %%
# FINAL DATASET
overview_A_2.extend(overview_B_2)
# Out:
# shape: (76_362, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────┬────────────────┬───────────────┬───────────────┐
# │ profileId ┆ vehicle        ┆ kilometers ┆ insurance     ┆ … ┆ Doors ┆ Fuel_Tank_Capa ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---       ┆ ---            ┆ ---        ┆ ---           ┆   ┆ ---   ┆ city_(litres)  ┆ (rows)        ┆ ity_(persons) │
# │ str       ┆ str            ┆ f64        ┆ str           ┆   ┆ i64   ┆ ---            ┆ ---           ┆ ---           │
# │           ┆                ┆            ┆               ┆   ┆       ┆ f64            ┆ i64           ┆ i64           │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════╪════════════════╪═══════════════╪═══════════════╡
# │ S2725575  ┆ Mercedes-Benz  ┆ 6000.0     ┆ Third Party   ┆ … ┆ 5     ┆ 93.0           ┆ 2             ┆ 5             │
# ...

# %%
overview_A_2.shape
# Out:
# (76362, 33)

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %%
overview_A_2.columns
# Out:
# ['profileId',
#  'vehicle',
#  'kilometers',
#  'insurance',
#  'makeName',
#  'versionName',
#  'makeYear',
#  'makeMonth',
#  'city',
#  'noOfOwners',
#  'regType',
#  'price',
#  'modelName',
#  'state',
#  'transmission',
#  'Mileage (ARAI)',
#  'Displacement_(cc)',
#  'Max_Power_(bhp)',
#  'Max_Power_at_rpm',
#  'Max_Torque_(Nm)',
#  'Max_Torque_at_rpm',
#  'Fuel',
#  'Ground_Clearance_(mm)',
#  'Height_(mm)',
#  'Kerb_Weight_(mm)',
#  'Length_(mm)',
#  'Wheelbase_(mm)',
#  'Width_(mm)',
#  'Bootspace_(litres)',
#  'Doors',
#  'Fuel_Tank_Capacity_(litres)',
#  'Seating_Rows_(rows)',
#  'Seating_Capacity_(persons)']

# %% [markdown]
# ### RENAMING COLUMNS

# %% [markdown]
# * Renaming the columns with proper and understandable names.

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ vehicle       ┆ kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %%
overview_A_2 = overview_A_2.rename(
                                    {'vehicle':'Car',
                                     'kilometers':'Kilometers',
                                     'insurance':'Insurance_Type',
                                     'makeName':'Make',
                                     'versionName':'Version',
                                     'makeYear':'Year_Made',
                                     'makeMonth':'Month_Made',
                                     'city':'City',
                                     'noOfOwners':'No_Of_Owners',
                                     'regType':'Registration_Type',
                                     'price':'Price_(Rs)',
                                     'modelName':'Model',
                                     'state':'State',
                                     'transmission':'Transmission_Type',
                                     'Mileage (ARAI)':'Mileage_(kmpl)',
                                     'Kerb_Weight_(mm)':'Kerb_Weight_(kg)'
                                    })

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬───────────────┬──────────────┬───┬──────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car           ┆ Kilometers   ┆ … ┆ Doors    ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---           ┆ ---          ┆   ┆ ---      ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str           ┆ f64          ┆   ┆ f64      ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆               ┆              ┆   ┆          ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪═══════════════╪══════════════╪═══╪══════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %% [markdown]
# ### CHECKING COLUMNS AND MAKING NECESSARY CORRECTIONS

# %% [markdown]
# * **correcting registration type values**

# %%
# No of Owners had unregistered car

list(overview_A_2['No_Of_Owners'].unique().sort(descending = True))

#.sort(descending = True)
# Out:
# ['Unregistered Car',
#  'Unregistered',
#  'Third',
#  'Second',
#  'Fourth',
#  'First',
#  '4 or More']

# %%
# correcting the values
overview_A_2 = overview_A_2.with_columns(pl.col('No_Of_Owners').replace({'Unregistered Car':'Unregistered'}))

# %%
# Registration_Type has none the values

list(overview_A_2['Registration_Type'].unique().sort(descending = True))
# Out:
# [None, 'Taxi', 'Individual', 'Corporate']

# %% [markdown]
# * **updating None values with 'Not Available'**

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Registration_Type').is_null()).then(pl.lit('Not Available')).otherwise(pl.col('Registration_Type')).alias('new'))

# %%
overview_A_2 = overview_A_2.drop('Registration_Type').rename({'new':'Registration_Type'})

# %%
list(overview_A_2['Registration_Type'].unique().sort(descending = True))
# Out:
# ['Taxi', 'Not Available', 'Individual', 'Corporate']

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬──────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ describe   ┆ profileId ┆ Car          ┆ Kilometers   ┆ … ┆ Fuel_Tank_Ca ┆ Seating_Rows ┆ Seating_Capa ┆ Registration │
# │ ---        ┆ ---       ┆ ---          ┆ ---          ┆   ┆ pacity_(litr ┆ _(rows)      ┆ city_(person ┆ _Type        │
# │ str        ┆ str       ┆ str          ┆ f64          ┆   ┆ es)          ┆ ---          ┆ s)           ┆ ---          │
# │            ┆           ┆              ┆              ┆   ┆ ---          ┆ f64          ┆ ---          ┆ str          │
# │            ┆           ┆              ┆              ┆   ┆ f64          ┆              ┆ f64          ┆              │
# ╞════════════╪═══════════╪══════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# ...

# %%
list(overview_A_2['Transmission_Type'].unique().sort(descending = True))
# Out:
# [None, 'Manual', 'Automatic']

# %%
overview_A_2.write_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-III\overview.csv')

# %%
list(overview_A_2['Transmission_Type'].unique().sort(descending = True))
# Out:
# [None, 'Manual', 'Automatic']

# %%
overview_A_2.filter(overview_A_2['Transmission_Type'].is_null())
# Out:
# shape: (6, 33)
# ┌───────────┬──────────────┬────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ profileId ┆ Car          ┆ Kilometers ┆ Insurance_Ty ┆ … ┆ Fuel_Tank_Ca ┆ Seating_Rows ┆ Seating_Capa ┆ Registration │
# │ ---       ┆ ---          ┆ ---        ┆ pe           ┆   ┆ pacity_(litr ┆ _(rows)      ┆ city_(person ┆ _Type        │
# │ str       ┆ str          ┆ f64        ┆ ---          ┆   ┆ es)          ┆ ---          ┆ s)           ┆ ---          │
# │           ┆              ┆            ┆ str          ┆   ┆ ---          ┆ i64          ┆ ---          ┆ str          │
# │           ┆              ┆            ┆              ┆   ┆ f64          ┆              ┆ i64          ┆              │
# ╞═══════════╪══════════════╪════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# ...

# %% [markdown]
# * **Replacing Null Transmission_Type with 'Not Available'**

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Transmission_Type').is_null()).then(pl.lit('Not Available')).otherwise(pl.col('Transmission_Type')).alias('new'))

# %%
overview_A_2.filter(overview_A_2['Transmission_Type'].is_null())
# Out:
# shape: (6, 34)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬──────────────┬──────────────┬───────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Seating_Rows_ ┆ Seating_Capa ┆ Registration ┆ new       │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ (rows)        ┆ city_(person ┆ _Type        ┆ ---       │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ ---           ┆ s)           ┆ ---          ┆ str       │
# │           ┆               ┆            ┆ str           ┆   ┆ i64           ┆ ---          ┆ str          ┆           │
# │           ┆               ┆            ┆               ┆   ┆               ┆ i64          ┆              ┆           │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪══════════════╪══════════════╪═══════════╡
# ...

# %%
overview_A_2.filter(overview_A_2['Transmission_Type']==overview_A_2['new'])
# Out:
# shape: (76_356, 34)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬──────────────┬──────────────┬───────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Seating_Rows_ ┆ Seating_Capa ┆ Registration ┆ new       │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ (rows)        ┆ city_(person ┆ _Type        ┆ ---       │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ ---           ┆ s)           ┆ ---          ┆ str       │
# │           ┆               ┆            ┆ str           ┆   ┆ i64           ┆ ---          ┆ str          ┆           │
# │           ┆               ┆            ┆               ┆   ┆               ┆ i64          ┆              ┆           │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪══════════════╪══════════════╪═══════════╡
# ...

# %%
# removing Transmission Type and using 'new' column
overview_A_2 = overview_A_2.drop('Transmission_Type').rename({'new':'Transmission_Type'})

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬──────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ describe   ┆ profileId ┆ Car          ┆ Kilometers   ┆ … ┆ Seating_Rows ┆ Seating_Capa ┆ Registration ┆ Transmission │
# │ ---        ┆ ---       ┆ ---          ┆ ---          ┆   ┆ _(rows)      ┆ city_(person ┆ _Type        ┆ _Type        │
# │ str        ┆ str       ┆ str          ┆ f64          ┆   ┆ ---          ┆ s)           ┆ ---          ┆ ---          │
# │            ┆           ┆              ┆              ┆   ┆ f64          ┆ ---          ┆ str          ┆ str          │
# │            ┆           ┆              ┆              ┆   ┆              ┆ f64          ┆              ┆              │
# ╞════════════╪═══════════╪══════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# ...

# %%
list(overview_A_2['Mileage_(kmpl)'].unique().sort(descending = True))
# Out:
# [None,
#  140.0,
#  47.45,
#  36.0,
#  35.6,
#  34.43,
#  34.05,
#  33.85,
#  33.54,
#  33.44,
#  32.73,
#  32.52,
#  32.26,
#  31.79,
#  31.59,
#  31.5,
#  31.19,
#  31.12,
#  30.9,
#  30.61,
#  30.48,
#  30.47,
#  30.0,
#  28.51,
#  28.4,
#  28.09,
#  28.0,
#  27.97,
#  27.62,
#  27.4,
#  27.39,
#  27.3,
#  27.28,
#  27.1,
#  26.99,
#  26.83,
#  26.82,
#  26.8,
#  26.78,
#  26.68,
#  26.6,
#  26.59,
#  26.5,
#  26.49,
#  26.4,
#  26.32,
#  26.209999084472656,
#  26.2,
#  26.11,
#  26.1,
#  26.0,
#  25.83,
#  25.8,
#  25.6,
#  25.51,
#  25.5,
#  25.47,
#  25.44,
#  25.4,
#  25.35,
#  25.32,
#  25.31999969482422,
#  25.31,
#  25.3,
#  25.24,
#  25.2,
#  25.19,
#  25.17,
#  25.11,
#  25.01,
#  25.0,
#  24.97,
#  24.95,
#  24.9,
#  24.8,
#  24.76,
#  24.75,
#  24.7,
#  24.6,
#  24.59,
#  24.52,
#  24.5,
#  24.43,
#  24.4,
#  24.39,
#  24.35,
#  24.29,
#  24.200000762939453,
#  24.2,
#  24.12,
#  24.1,
#  24.08,
#  24.07,
#  24.04,
#  24.0,
#  23.97,
#  23.95,
#  23.9,
#  23.87,
# ...

# %% [markdown]
# * **Replacing Null values with NaN for Mileage**

# %%
69_084+7278.0
# Out:
# 76362.0

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Mileage_(kmpl)').is_null()).then(np.nan).otherwise(pl.col('Mileage_(kmpl)')).alias('new'))

# %%
overview_A_2.filter(overview_A_2['Mileage_(kmpl)'].is_null())
# Out:
# shape: (7_278, 34)
# ┌───────────┬────────────────┬────────────┬────────────────┬───┬────────────────┬────────────────┬───────────────┬─────┐
# │ profileId ┆ Car            ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Seating_Capaci ┆ Registration_T ┆ Transmission_ ┆ new │
# │ ---       ┆ ---            ┆ ---        ┆ ---            ┆   ┆ ty_(persons)   ┆ ype            ┆ Type          ┆ --- │
# │ str       ┆ str            ┆ f64        ┆ str            ┆   ┆ ---            ┆ ---            ┆ ---           ┆ f64 │
# │           ┆                ┆            ┆                ┆   ┆ i64            ┆ str            ┆ str           ┆     │
# ╞═══════════╪════════════════╪════════════╪════════════════╪═══╪════════════════╪════════════════╪═══════════════╪═════╡
# │ S2733827  ┆ Maruti Suzuki  ┆ 100000.0   ┆ Not Available  ┆ … ┆ null           ┆ Individual     ┆ Manual        ┆ NaN │
# ...

# %%
overview_A_2 = overview_A_2.drop('Mileage_(kmpl)').rename({'new':'Mileage_(kmpl)'})

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬───────────────┬───────────────┬───────────────┬─────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Seating_Capac ┆ Registration_ ┆ Transmission_ ┆ Mileage │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ ity_(persons) ┆ Type          ┆ Type          ┆ ---     │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---           ┆ ---           ┆ ---           ┆ f64     │
# │            ┆           ┆                ┆              ┆   ┆ f64           ┆ str           ┆ str           ┆         │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362.0       ┆ 76362         ┆ 76362         ┆ 76362.0 │
# ...

# %% [markdown]
# * **Replacing Null values with NaN for Displacement**

# %%
overview_A_2.filter(overview_A_2['Displacement_(cc)'].is_null())
# Out:
# shape: (2_004, 33)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬─────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Seating_Capac ┆ Registration_ ┆ Transmission_ ┆ Mileage │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ ity_(persons) ┆ Type          ┆ Type          ┆ ---     │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ ---           ┆ ---           ┆ ---           ┆ f64     │
# │           ┆               ┆            ┆ str           ┆   ┆ i64           ┆ str           ┆ str           ┆         │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═════════╡
# │ S2733827  ┆ Maruti Suzuki ┆ 100000.0   ┆ Not Available ┆ … ┆ null          ┆ Individual    ┆ Manual        ┆ NaN     │
# ...

# %%
list(overview_A_2['Displacement_(cc)'].unique().sort(descending = True))
# Out:
# [None,
#  nan,
#  6752.0,
#  6749.0,
#  6592.0,
#  6417.0,
#  6299.0,
#  6208.0,
#  5998.0,
#  5980.0,
#  5935.0,
#  5663.0,
#  5461.0,
#  5439.0,
#  5204.0,
#  5000.0,
#  4999.0,
#  4951.0,
#  4806.0,
#  4663.0,
#  4461.0,
#  4395.0,
#  4367.0,
#  4163.0,
#  4134.0,
#  3998.0,
#  3996.0,
#  3993.0,
#  3982.0,
#  3956.0,
#  3902.0,
#  3800.0,
#  3799.0,
#  3696.0,
#  3628.0,
#  3605.0,
#  3604.0,
#  3598.0,
#  3597.0,
#  3498.0,
#  3496.0,
#  3471.0,
#  3456.0,
#  3436.0,
#  3346.0,
#  3200.0,
#  3198.0,
#  3197.0,
#  3192.0,
#  2999.0,
#  2998.0,
#  2997.0,
#  2996.0,
#  2995.0,
#  2994.0,
#  2993.0,
#  2987.0,
#  2982.0,
#  2979.0,
#  2967.0,
#  2956.0,
#  2953.0,
#  2925.0,
#  2894.0,
#  2835.0,
#  2800.0,
#  2799.0,
#  2776.0,
#  2771.0,
#  2755.0,
#  2736.0,
#  2706.0,
#  2698.0,
#  2696.0,
#  2694.0,
#  2685.0,
#  2656.0,
#  2650.0,
#  2609.0,
#  2596.0,
#  2523.0,
#  2499.0,
#  2498.0,
#  2497.0,
#  2496.0,
#  2494.0,
#  2489.0,
#  2487.0,
#  2477.0,
#  2446.0,
#  2400.0,
# ...

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Displacement_(cc)').is_null()).then(np.nan).otherwise(pl.col('Displacement_(cc)')).alias('new'))

# %%
overview_A_2.filter(overview_A_2['Displacement_(cc)'] == overview_A_2['new'] )
# Out:
# shape: (74_269, 34)
# ┌───────────┬─────────────────┬────────────┬────────────────┬───┬─────────────────┬─────────────────┬─────────┬────────┐
# │ profileId ┆ Car             ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Registration_Ty ┆ Transmission_Ty ┆ Mileage ┆ new    │
# │ ---       ┆ ---             ┆ ---        ┆ ---            ┆   ┆ pe              ┆ pe              ┆ ---     ┆ ---    │
# │ str       ┆ str             ┆ f64        ┆ str            ┆   ┆ ---             ┆ ---             ┆ f64     ┆ f64    │
# │           ┆                 ┆            ┆                ┆   ┆ str             ┆ str             ┆         ┆        │
# ╞═══════════╪═════════════════╪════════════╪════════════════╪═══╪═════════════════╪═════════════════╪═════════╪════════╡
# │ S2725575  ┆ Mercedes-Benz   ┆ 6000.0     ┆ Third Party    ┆ … ┆ Individual      ┆ Automatic       ┆ 14.0    ┆ 1950.0 │
# ...

# %%
overview_A_2.filter(overview_A_2['new'].is_nan())
# Out:
# shape: (2_093, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬──────────────────┬──────────────────┬─────────┬─────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Registration_Typ ┆ Transmission_Typ ┆ Mileage ┆ new │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ e                ┆ e                ┆ ---     ┆ --- │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---              ┆ ---              ┆ f64     ┆ f64 │
# │           ┆                  ┆            ┆                ┆   ┆ str              ┆ str              ┆         ┆     │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪══════════════════╪══════════════════╪═════════╪═════╡
# │ S2733827  ┆ Maruti Suzuki    ┆ 100000.0   ┆ Not Available  ┆ … ┆ Individual       ┆ Manual           ┆ NaN     ┆ NaN │
# ...

# %%
(2_093+74_269)
# Out:
# 76362

# %%
overview_A_2 = overview_A_2.drop('Displacement_(cc)').rename({'new':'Displacement_(cc)'})

# %%
list(overview_A_2['Displacement_(cc)'].unique().sort(descending = True))
# Out:
# [nan,
#  6752.0,
#  6749.0,
#  6592.0,
#  6417.0,
#  6299.0,
#  6208.0,
#  5998.0,
#  5980.0,
#  5935.0,
#  5663.0,
#  5461.0,
#  5439.0,
#  5204.0,
#  5000.0,
#  4999.0,
#  4951.0,
#  4806.0,
#  4663.0,
#  4461.0,
#  4395.0,
#  4367.0,
#  4163.0,
#  4134.0,
#  3998.0,
#  3996.0,
#  3993.0,
#  3982.0,
#  3956.0,
#  3902.0,
#  3800.0,
#  3799.0,
#  3696.0,
#  3628.0,
#  3605.0,
#  3604.0,
#  3598.0,
#  3597.0,
#  3498.0,
#  3496.0,
#  3471.0,
#  3456.0,
#  3436.0,
#  3346.0,
#  3200.0,
#  3198.0,
#  3197.0,
#  3192.0,
#  2999.0,
#  2998.0,
#  2997.0,
#  2996.0,
#  2995.0,
#  2994.0,
#  2993.0,
#  2987.0,
#  2982.0,
#  2979.0,
#  2967.0,
#  2956.0,
#  2953.0,
#  2925.0,
#  2894.0,
#  2835.0,
#  2800.0,
#  2799.0,
#  2776.0,
#  2771.0,
#  2755.0,
#  2736.0,
#  2706.0,
#  2698.0,
#  2696.0,
#  2694.0,
#  2685.0,
#  2656.0,
#  2650.0,
#  2609.0,
#  2596.0,
#  2523.0,
#  2499.0,
#  2498.0,
#  2497.0,
#  2496.0,
#  2494.0,
#  2489.0,
#  2487.0,
#  2477.0,
#  2446.0,
#  2400.0,
#  2393.0,
# ...

# %% [markdown]
# * **Replacing Null values with NaN for Max_Power_(bhp)**

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬───────────────┬───────────────┬─────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Registration_ ┆ Transmission_ ┆ Mileage ┆ Displacement_ │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ Type          ┆ Type          ┆ ---     ┆ (cc)          │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---           ┆ ---           ┆ f64     ┆ ---           │
# │            ┆           ┆                ┆              ┆   ┆ str           ┆ str           ┆         ┆ f64           │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪═══════════════╪═══════════════╪═════════╪═══════════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362         ┆ 76362         ┆ 76362.0 ┆ 76362.0       │
# ...

# %%
overview_A_2.filter(overview_A_2['Max_Power_(bhp)'].is_null())
# Out:
# shape: (2_072, 33)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬─────────┬───────────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Registration_ ┆ Transmission_ ┆ Mileage ┆ Displacement_ │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ Type          ┆ Type          ┆ ---     ┆ (cc)          │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ ---           ┆ ---           ┆ f64     ┆ ---           │
# │           ┆               ┆            ┆ str           ┆   ┆ str           ┆ str           ┆         ┆ f64           │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═════════╪═══════════════╡
# │ S2733827  ┆ Maruti Suzuki ┆ 100000.0   ┆ Not Available ┆ … ┆ Individual    ┆ Manual        ┆ NaN     ┆ NaN           │
# ...

# %%
list(overview_A_2['Max_Power_(bhp)'].unique().sort(descending = True))
# Out:
# [None,
#  660.0,
#  650.0,
#  621.0,
#  617.0,
#  616.0,
#  603.0,
#  602.0,
#  577.0,
#  575.0,
#  571.0,
#  570.0,
#  567.0,
#  563.0,
#  560.0,
#  553.0,
#  552.0,
#  549.0,
#  542.0,
#  533.0,
#  523.0,
#  512.0,
#  510.0,
#  507.0,
#  503.0,
#  500.0,
#  494.0,
#  475.0,
#  463.0,
#  462.0,
#  457.0,
#  453.0,
#  450.0,
#  444.0,
#  440.0,
#  429.0,
#  425.0,
#  424.0,
#  421.0,
#  420.0,
#  407.0,
#  405.0,
#  400.0,
#  396.0,
#  394.0,
#  385.0,
#  382.0,
#  380.0,
#  375.0,
#  369.86,
#  368.0,
#  362.0,
#  357.0,
#  355.0,
#  349.0,
#  346.0,
#  344.0,
#  335.0,
#  333.0,
#  329.0,
#  328.0,
#  326.0,
#  325.0,
#  320.0,
#  313.0,
#  310.0,
#  308.0,
#  306.0,
#  304.0,
#  302.0,
#  301.0,
#  300.0,
#  296.0,
#  295.0,
#  290.0,
#  289.0,
#  286.0,
#  282.0,
#  280.0,
#  276.0,
#  275.0,
#  272.0,
#  271.0,
#  268.0,
#  265.0,
#  262.0,
#  261.0,
#  260.0,
#  259.0,
#  258.0,
#  255.0,
#  254.0,
#  252.0,
#  250.0,
#  248.0,
#  247.0,
#  245.0,
#  244.0,
#  242.0,
#  241.0,
# ...

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Max_Power_(bhp)').is_null()).then(np.nan).otherwise(pl.col('Max_Power_(bhp)')).alias('new'))

# %%
overview_A_2.filter(overview_A_2['Max_Power_(bhp)'] == overview_A_2['new'] )
# Out:
# shape: (74_290, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬─────────────────┬─────────┬─────────────────┬───────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Transmission_Ty ┆ Mileage ┆ Displacement_(c ┆ new   │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ pe              ┆ ---     ┆ c)              ┆ ---   │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---             ┆ f64     ┆ ---             ┆ f64   │
# │           ┆                  ┆            ┆                ┆   ┆ str             ┆         ┆ f64             ┆       │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪═════════════════╪═════════╪═════════════════╪═══════╡
# │ S2725575  ┆ Mercedes-Benz    ┆ 6000.0     ┆ Third Party    ┆ … ┆ Automatic       ┆ 14.0    ┆ 1950.0          ┆ 241.0 │
# ...

# %%
overview_A_2.filter(overview_A_2['new'].is_nan())
# Out:
# shape: (2_072, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬──────────────────┬─────────┬──────────────────┬─────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Transmission_Typ ┆ Mileage ┆ Displacement_(cc ┆ new │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ e                ┆ ---     ┆ )                ┆ --- │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---              ┆ f64     ┆ ---              ┆ f64 │
# │           ┆                  ┆            ┆                ┆   ┆ str              ┆         ┆ f64              ┆     │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪══════════════════╪═════════╪══════════════════╪═════╡
# │ S2733827  ┆ Maruti Suzuki    ┆ 100000.0   ┆ Not Available  ┆ … ┆ Manual           ┆ NaN     ┆ NaN              ┆ NaN │
# ...

# %%
overview_A_2 = overview_A_2.drop('Max_Power_(bhp)').rename({'new':'Max_Power_(bhp)'})

# %%
list(overview_A_2['Max_Power_(bhp)'].unique().sort(descending = True))
# Out:
# [nan,
#  660.0,
#  650.0,
#  621.0,
#  617.0,
#  616.0,
#  603.0,
#  602.0,
#  577.0,
#  575.0,
#  571.0,
#  570.0,
#  567.0,
#  563.0,
#  560.0,
#  553.0,
#  552.0,
#  549.0,
#  542.0,
#  533.0,
#  523.0,
#  512.0,
#  510.0,
#  507.0,
#  503.0,
#  500.0,
#  494.0,
#  475.0,
#  463.0,
#  462.0,
#  457.0,
#  453.0,
#  450.0,
#  444.0,
#  440.0,
#  429.0,
#  425.0,
#  424.0,
#  421.0,
#  420.0,
#  407.0,
#  405.0,
#  400.0,
#  396.0,
#  394.0,
#  385.0,
#  382.0,
#  380.0,
#  375.0,
#  369.86,
#  368.0,
#  362.0,
#  357.0,
#  355.0,
#  349.0,
#  346.0,
#  344.0,
#  335.0,
#  333.0,
#  329.0,
#  328.0,
#  326.0,
#  325.0,
#  320.0,
#  313.0,
#  310.0,
#  308.0,
#  306.0,
#  304.0,
#  302.0,
#  301.0,
#  300.0,
#  296.0,
#  295.0,
#  290.0,
#  289.0,
#  286.0,
#  282.0,
#  280.0,
#  276.0,
#  275.0,
#  272.0,
#  271.0,
#  268.0,
#  265.0,
#  262.0,
#  261.0,
#  260.0,
#  259.0,
#  258.0,
#  255.0,
#  254.0,
#  252.0,
#  250.0,
#  248.0,
#  247.0,
#  245.0,
#  244.0,
#  242.0,
#  241.0,
# ...

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬───────────────┬─────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Transmission_ ┆ Mileage ┆ Displacement_ ┆ Max_Power_(bh │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ Type          ┆ ---     ┆ (cc)          ┆ p)            │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---           ┆ f64     ┆ ---           ┆ ---           │
# │            ┆           ┆                ┆              ┆   ┆ str           ┆         ┆ f64           ┆ f64           │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪═══════════════╪═════════╪═══════════════╪═══════════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362         ┆ 76362.0 ┆ 76362.0       ┆ 76362.0       │
# ...

# %% [markdown]
# * **Replacing Null values with NaN for Max_Torque_(Nm))**

# %%
list(overview_A_2['Max_Torque_(Nm)'].unique().sort(descending = True))
# Out:
# [None,
#  1020.0,
#  1000.0,
#  900.0,
#  850.0,
#  830.0,
#  800.0,
#  780.0,
#  770.0,
#  760.0,
#  750.0,
#  740.0,
#  700.0,
#  689.0,
#  680.0,
#  660.0,
#  650.0,
#  640.0,
#  630.0,
#  625.0,
#  624.0,
#  620.0,
#  619.0,
#  617.0,
#  600.0,
#  580.0,
#  570.0,
#  560.0,
#  550.0,
#  540.0,
#  535.0,
#  530.0,
#  520.0,
#  515.0,
#  510.0,
#  505.0,
#  500.0,
#  490.0,
#  480.0,
#  475.0,
#  470.0,
#  460.0,
#  456.0,
#  450.0,
#  441.0,
#  440.0,
#  437.0,
#  436.0,
#  430.0,
#  425.0,
#  424.0,
#  421.0,
#  420.0,
#  416.0,
#  410.0,
#  402.0,
#  400.0,
#  390.0,
#  385.0,
#  383.0,
#  382.0,
#  380.0,
#  373.5,
#  370.0,
#  365.0,
#  363.0,
#  362.0,
#  360.0,
#  355.0,
#  350.0,
#  347.0,
#  345.0,
#  343.0,
#  340.0,
#  339.0,
#  335.0,
#  330.0,
#  327.0,
#  323.0,
#  321.0,
#  320.0,
#  319.0,
#  315.0,
#  314.0,
#  305.0,
#  300.0,
#  292.0,
#  290.0,
#  285.0,
#  282.0,
#  280.0,
#  277.0,
#  270.0,
#  265.0,
#  263.0,
#  260.0,
#  259.0,
#  255.0,
#  254.0,
# ...

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Max_Torque_(Nm)').is_null()).then(np.nan).otherwise(pl.col('Max_Torque_(Nm)')).alias('new'))

# %%
overview_A_2.filter(overview_A_2['Max_Torque_(Nm)'] == overview_A_2['new'] ).shape[0]+overview_A_2.filter(overview_A_2['new'].is_nan()).shape[0]
# Out:
# 76362

# %%
overview_A_2 = overview_A_2.drop('Max_Torque_(Nm)').rename({'new':'Max_Torque_(Nm)'})

# %%
list(overview_A_2['Max_Torque_(Nm)'].unique().sort(descending = True))
# Out:
# [nan,
#  1020.0,
#  1000.0,
#  900.0,
#  850.0,
#  830.0,
#  800.0,
#  780.0,
#  770.0,
#  760.0,
#  750.0,
#  740.0,
#  700.0,
#  689.0,
#  680.0,
#  660.0,
#  650.0,
#  640.0,
#  630.0,
#  625.0,
#  624.0,
#  620.0,
#  619.0,
#  617.0,
#  600.0,
#  580.0,
#  570.0,
#  560.0,
#  550.0,
#  540.0,
#  535.0,
#  530.0,
#  520.0,
#  515.0,
#  510.0,
#  505.0,
#  500.0,
#  490.0,
#  480.0,
#  475.0,
#  470.0,
#  460.0,
#  456.0,
#  450.0,
#  441.0,
#  440.0,
#  437.0,
#  436.0,
#  430.0,
#  425.0,
#  424.0,
#  421.0,
#  420.0,
#  416.0,
#  410.0,
#  402.0,
#  400.0,
#  390.0,
#  385.0,
#  383.0,
#  382.0,
#  380.0,
#  373.5,
#  370.0,
#  365.0,
#  363.0,
#  362.0,
#  360.0,
#  355.0,
#  350.0,
#  347.0,
#  345.0,
#  343.0,
#  340.0,
#  339.0,
#  335.0,
#  330.0,
#  327.0,
#  323.0,
#  321.0,
#  320.0,
#  319.0,
#  315.0,
#  314.0,
#  305.0,
#  300.0,
#  292.0,
#  290.0,
#  285.0,
#  282.0,
#  280.0,
#  277.0,
#  270.0,
#  265.0,
#  263.0,
#  260.0,
#  259.0,
#  255.0,
#  254.0,
#  253.0,
# ...

# %% [markdown]
# * **Replacing Null values with NaN for multiple columns**

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬─────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Mileage ┆ Displacement_ ┆ Max_Power_(bh ┆ Max_Torque_(N │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ ---     ┆ (cc)          ┆ p)            ┆ m)            │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ f64     ┆ ---           ┆ ---           ┆ ---           │
# │            ┆           ┆                ┆              ┆   ┆         ┆ f64           ┆ f64           ┆ f64           │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪═════════╪═══════════════╪═══════════════╪═══════════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362.0 ┆ 76362.0       ┆ 76362.0       ┆ 76362.0       │
# ...

# %%
cols =  ['Max_Power_at_rpm',
         'Max_Torque_at_rpm',
         'Ground_Clearance_(mm)',
         'Height_(mm)',
         'Kerb_Weight_(kg)',
         'Length_(mm)',
         'Wheelbase_(mm)',
         'Width_(mm)',
         'Bootspace_(litres)',
         'Doors',
         'Fuel_Tank_Capacity_(litres)',
         'Seating_Rows_(rows)',
         'Seating_Capacity_(persons)']

# %%
for i in cols:
    overview_A_2 = overview_A_2.with_columns(pl.when(pl.col(i).is_null()).then(np.nan).otherwise(pl.col(i)).alias('new'))
    a = overview_A_2.filter(overview_A_2[i] == overview_A_2['new']).shape[0] 
    b = overview_A_2.filter(overview_A_2['new'].is_nan()).shape[0]
    c = overview_A_2.shape[0] 
    if(a+b==c):
        overview_A_2 = overview_A_2.drop(i).rename({'new':i})
        print('done',i)
    else:
        continue
# Out:
# done Max_Power_at_rpm
# done Max_Torque_at_rpm
# done Ground_Clearance_(mm)
# done Height_(mm)
# done Kerb_Weight_(kg)
# done Length_(mm)
# done Wheelbase_(mm)
# done Width_(mm)
# done Bootspace_(litres)
# done Doors
# done Fuel_Tank_Capacity_(litres)
# done Seating_Rows_(rows)
# done Seating_Capacity_(persons)

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬─────────┬───────────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Doors   ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ ---     ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ f64     ┆ )             ┆ ---           ┆ ---           │
# │            ┆           ┆                ┆              ┆   ┆         ┆ ---           ┆ f64           ┆ f64           │
# │            ┆           ┆                ┆              ┆   ┆         ┆ f64           ┆               ┆               │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪═════════╪═══════════════╪═══════════════╪═══════════════╡
# ...

# %% [markdown]
# * correcting the NaN value in Fuel to Not Available

# %%
type(overview_A_2['Fuel'].unique().sort(descending = True)[1]
# Out:
# str

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Fuel')=='NaN').then(pl.lit('Not Available')).otherwise(pl.col('Fuel')).alias('new'))

# %%
overview_A_2 = overview_A_2.drop('Fuel').rename({'new':'Fuel'})

# %%
overview_A_2.filter(pl.col('Fuel') == 'Not Available')
# Out:
# shape: (6, 33)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬──────────────┬──────────────┬───────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Fuel_Tank_Cap ┆ Seating_Rows ┆ Seating_Capa ┆ Fuel      │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ acity_(litres ┆ _(rows)      ┆ city_(person ┆ ---       │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ )             ┆ ---          ┆ s)           ┆ str       │
# │           ┆               ┆            ┆ str           ┆   ┆ ---           ┆ f64          ┆ ---          ┆           │
# │           ┆               ┆            ┆               ┆   ┆ f64           ┆              ┆ f64          ┆           │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪══════════════╪══════════════╪═══════════╡
# ...

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬────────────────┬───────────────┬───────────────┬────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Fuel_Tank_Capa ┆ Seating_Rows_ ┆ Seating_Capac ┆ Fuel   │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ city_(litres)  ┆ (rows)        ┆ ity_(persons) ┆ ---    │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---            ┆ ---           ┆ ---           ┆ str    │
# │            ┆           ┆                ┆              ┆   ┆ f64            ┆ f64           ┆ f64           ┆        │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪════════════════╪═══════════════╪═══════════════╪════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362.0        ┆ 76362.0       ┆ 76362.0       ┆ 76362  │
# ...

# %% [markdown]
# * **checking if displacement is valid and updating the correct values**

# %%
list(overview_A_2['Displacement_(cc)'].unique().sort(descending = False))
# Out:
# [4.0,
#  624.0,
#  793.0,
#  796.0,
#  799.0,
#  814.0,
#  936.0,
#  993.0,
#  995.0,
#  998.0,
#  999.0,
#  1047.0,
#  1061.0,
#  1086.0,
#  1108.0,
#  1120.0,
#  1150.0,
#  1172.0,
#  1186.0,
#  1193.0,
#  1194.0,
#  1196.0,
#  1197.0,
#  1198.0,
#  1199.0,
#  1248.0,
#  1297.0,
#  1298.0,
#  1299.0,
#  1330.0,
#  1332.0,
#  1336.0,
#  1339.0,
#  1341.0,
#  1349.0,
#  1353.0,
#  1364.0,
#  1368.0,
#  1373.0,
#  1388.0,
#  1389.0,
#  1390.0,
#  1395.0,
#  1396.0,
#  1399.0,
#  1405.0,
#  1422.0,
#  1451.0,
#  1461.0,
#  1462.0,
#  1468.0,
#  1482.0,
#  1490.0,
#  1493.0,
#  1495.0,
#  1496.0,
#  1497.0,
#  1498.0,
#  1499.0,
#  1527.0,
#  1582.0,
#  1586.0,
#  1590.0,
#  1591.0,
#  1595.0,
#  1596.0,
#  1597.0,
#  1598.0,
#  1599.0,
#  1781.0,
#  1794.0,
#  1795.0,
#  1796.0,
#  1797.0,
#  1798.0,
#  1799.0,
#  1817.0,
#  1896.0,
#  1898.0,
#  1948.0,
#  1950.0,
#  1956.0,
#  1968.0,
#  1969.0,
#  1984.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1991.0,
#  1993.0,
#  1994.0,
#  1995.0,
# ...

# %%
list(overview_A_2.filter(pl.col('Displacement_(cc)') == 4)['Car'])
# Out:
# ['Toyota Etios VD', 'Toyota Corolla Altis Diesel Ltd']

# %%
overview_A_2.filter(pl.col('Displacement_(cc)') == 4)
# Out:
# shape: (2, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬────────┐
# │ profileId ┆ Car            ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac ┆ Fuel   │
# │ ---       ┆ ---            ┆ ---        ┆ e             ┆   ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) ┆ ---    │
# │ str       ┆ str            ┆ f64        ┆ ---           ┆   ┆ )             ┆ ---           ┆ ---           ┆ str    │
# │           ┆                ┆            ┆ str           ┆   ┆ ---           ┆ f64           ┆ f64           ┆        │
# │           ┆                ┆            ┆               ┆   ┆ f64           ┆               ┆               ┆        │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪════════╡
# ...

# %%
list(overview_A_2['profileId']).index('D4112829')
# Out:
# 75762

# %%
overview_A_2[75762,'Displacement_(cc)']=1364.0

# %%
list(overview_A_2['profileId']).index('S2713851')
# Out:
# 75946

# %%
overview_A_2[75946,'Displacement_(cc)']=1798.00

# %%
overview_A_2.filter(pl.col('Displacement_(cc)') == 4)
# Out:
# shape: (0, 33)
# ┌───────────┬─────┬────────────┬────────────────┬───┬───────────────────┬───────────────────┬───────────────────┬──────┐
# │ profileId ┆ Car ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Fuel_Tank_Capacit ┆ Seating_Rows_(row ┆ Seating_Capacity_ ┆ Fuel │
# │ ---       ┆ --- ┆ ---        ┆ ---            ┆   ┆ y_(litres)        ┆ s)                ┆ (persons)         ┆ ---  │
# │ str       ┆ str ┆ f64        ┆ str            ┆   ┆ ---               ┆ ---               ┆ ---               ┆ str  │
# │           ┆     ┆            ┆                ┆   ┆ f64               ┆ f64               ┆ f64               ┆      │
# ╞═══════════╪═════╪════════════╪════════════════╪═══╪═══════════════════╪═══════════════════╪═══════════════════╪══════╡
# └───────────┴─────┴────────────┴────────────────┴───┴───────────────────┴───────────────────┴───────────────────┴──────┘

# %% [markdown]
# * **minimum values of torque and power are 0 but it should not be 0 hence replacing them with NaN**

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬────────────────┬───────────────┬───────────────┬────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Fuel_Tank_Capa ┆ Seating_Rows_ ┆ Seating_Capac ┆ Fuel   │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ city_(litres)  ┆ (rows)        ┆ ity_(persons) ┆ ---    │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---            ┆ ---           ┆ ---           ┆ str    │
# │            ┆           ┆                ┆              ┆   ┆ f64            ┆ f64           ┆ f64           ┆        │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪════════════════╪═══════════════╪═══════════════╪════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362.0        ┆ 76362.0       ┆ 76362.0       ┆ 76362  │
# ...

# %%
list(overview_A_2['Max_Power_(bhp)'].unique().sort(descending = False))
# Out:
# [0.0,
#  19.85,
#  25.0,
#  29.0,
#  33.0,
#  34.0,
#  35.0,
#  37.0,
#  38.0,
#  39.0,
#  40.0,
#  42.0,
#  46.0,
#  47.0,
#  48.0,
#  48.2,
#  52.0,
#  53.0,
#  53.5,
#  54.0,
#  55.0,
#  56.0,
#  57.0,
#  58.0,
#  59.0,
#  60.0,
#  61.0,
#  62.0,
#  63.0,
#  64.0,
#  65.0,
#  66.0,
#  67.0,
#  67.7,
#  68.0,
#  69.0,
#  70.0,
#  71.0,
#  72.0,
#  73.0,
#  74.0,
#  75.0,
#  76.0,
#  77.0,
#  78.0,
#  79.0,
#  80.0,
#  81.0,
#  82.0,
#  83.0,
#  84.0,
#  85.0,
#  86.0,
#  87.0,
#  88.0,
#  89.0,
#  90.0,
#  91.0,
#  92.0,
#  93.0,
#  94.0,
#  95.0,
#  97.0,
#  98.0,
#  99.0,
#  100.0,
#  101.0,
#  102.0,
#  103.0,
#  104.0,
#  105.0,
#  106.0,
#  107.0,
#  108.0,
#  109.0,
#  110.0,
#  112.0,
#  113.0,
#  114.0,
#  115.0,
#  116.0,
#  117.0,
#  118.0,
#  119.0,
#  120.0,
#  121.0,
#  122.0,
#  123.0,
#  124.0,
#  125.0,
#  126.0,
#  127.0,
#  128.0,
#  129.0,
#  130.0,
#  132.0,
#  134.0,
#  135.0,
#  136.0,
#  137.0,
#  138.0,
#  139.0,
#  140.0,
#  141.0,
#  142.0,
#  143.0,
# ...

# %%
overview_A_2.filter(pl.col('Max_Power_(bhp)') == 0.0)
# Out:
# shape: (13, 33)
# ┌───────────┬────────────────┬────────────┬───────────────┬───┬───────────────┬───────────────┬───────────────┬────────┐
# │ profileId ┆ Car            ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Fuel_Tank_Cap ┆ Seating_Rows_ ┆ Seating_Capac ┆ Fuel   │
# │ ---       ┆ ---            ┆ ---        ┆ e             ┆   ┆ acity_(litres ┆ (rows)        ┆ ity_(persons) ┆ ---    │
# │ str       ┆ str            ┆ f64        ┆ ---           ┆   ┆ )             ┆ ---           ┆ ---           ┆ str    │
# │           ┆                ┆            ┆ str           ┆   ┆ ---           ┆ f64           ┆ f64           ┆        │
# │           ┆                ┆            ┆               ┆   ┆ f64           ┆               ┆               ┆        │
# ╞═══════════╪════════════════╪════════════╪═══════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪════════╡
# ...

# %%
overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Max_Power_(bhp)') == 0.0).then(np.nan).otherwise(pl.col('Max_Power_(bhp)')).alias('new'))

# %%
(+13+2_072)
# Out:
# 2085

# %%
overview_A_2.filter(pl.col('new').is_nan())
# Out:
# shape: (2_085, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬──────────────────┬─────────────────┬──────────┬─────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Seating_Rows_(ro ┆ Seating_Capacit ┆ Fuel     ┆ new │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ ws)              ┆ y_(persons)     ┆ ---      ┆ --- │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---              ┆ ---             ┆ str      ┆ f64 │
# │           ┆                  ┆            ┆                ┆   ┆ f64              ┆ f64             ┆          ┆     │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪══════════════════╪═════════════════╪══════════╪═════╡
# │ S2733827  ┆ Maruti Suzuki    ┆ 100000.0   ┆ Not Available  ┆ … ┆ NaN              ┆ NaN             ┆ Petrol   ┆ NaN │
# ...

# %%
overview_A_2 = overview_A_2.drop('Max_Power_(bhp)').rename({'new':'Max_Power_(bhp)'})

# %%
overview_A_2.filter(pl.col('Max_Power_(bhp)')==0.0)
# Out:
# shape: (0, 33)
# ┌───────────┬─────┬────────────┬────────────────┬───┬────────────────────┬────────────────────┬──────┬─────────────────┐
# │ profileId ┆ Car ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Seating_Rows_(rows ┆ Seating_Capacity_( ┆ Fuel ┆ Max_Power_(bhp) │
# │ ---       ┆ --- ┆ ---        ┆ ---            ┆   ┆ )                  ┆ persons)           ┆ ---  ┆ ---             │
# │ str       ┆ str ┆ f64        ┆ str            ┆   ┆ ---                ┆ ---                ┆ str  ┆ f64             │
# │           ┆     ┆            ┆                ┆   ┆ f64                ┆ f64                ┆      ┆                 │
# ╞═══════════╪═════╪════════════╪════════════════╪═══╪════════════════════╪════════════════════╪══════╪═════════════════╡
# └───────────┴─────┴────────────┴────────────────┴───┴────────────────────┴────────────────────┴──────┴─────────────────┘

# %%
# correcting torque

overview_A_2 = overview_A_2.with_columns(pl.when(pl.col('Max_Torque_(Nm)') == 0.0).then(np.nan).otherwise(pl.col('Max_Torque_(Nm)')).alias('new'))

# %%
overview_A_2.filter(pl.col('new').is_nan())
# Out:
# shape: (2_085, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬──────────────────┬──────────┬─────────────────┬─────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Seating_Capacity ┆ Fuel     ┆ Max_Power_(bhp) ┆ new │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ _(persons)       ┆ ---      ┆ ---             ┆ --- │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---              ┆ str      ┆ f64             ┆ f64 │
# │           ┆                  ┆            ┆                ┆   ┆ f64              ┆          ┆                 ┆     │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪══════════════════╪══════════╪═════════════════╪═════╡
# │ S2733827  ┆ Maruti Suzuki    ┆ 100000.0   ┆ Not Available  ┆ … ┆ NaN              ┆ Petrol   ┆ NaN             ┆ NaN │
# ...

# %%
overview_A_2.filter(pl.col('Max_Torque_(Nm)') == pl.col('new'))
# Out:
# shape: (74_277, 34)
# ┌───────────┬──────────────────┬────────────┬────────────────┬───┬──────────────────┬────────┬─────────────────┬───────┐
# │ profileId ┆ Car              ┆ Kilometers ┆ Insurance_Type ┆ … ┆ Seating_Capacity ┆ Fuel   ┆ Max_Power_(bhp) ┆ new   │
# │ ---       ┆ ---              ┆ ---        ┆ ---            ┆   ┆ _(persons)       ┆ ---    ┆ ---             ┆ ---   │
# │ str       ┆ str              ┆ f64        ┆ str            ┆   ┆ ---              ┆ str    ┆ f64             ┆ f64   │
# │           ┆                  ┆            ┆                ┆   ┆ f64              ┆        ┆                 ┆       │
# ╞═══════════╪══════════════════╪════════════╪════════════════╪═══╪══════════════════╪════════╪═════════════════╪═══════╡
# │ S2725575  ┆ Mercedes-Benz    ┆ 6000.0     ┆ Third Party    ┆ … ┆ 5.0              ┆ Diesel ┆ 241.0           ┆ 500.0 │
# ...

# %%
74_277+2_085
# Out:
# 76362

# %%
overview_A_2 = overview_A_2.drop('Max_Torque_(Nm)').rename({'new':'Max_Torque_(Nm)'})

# %%
overview_A_2.filter(pl.col('Max_Torque_(Nm)').is_nan())
# Out:
# shape: (2_085, 33)
# ┌───────────┬───────────────┬────────────┬───────────────┬───┬───────────────┬──────────┬───────────────┬──────────────┐
# │ profileId ┆ Car           ┆ Kilometers ┆ Insurance_Typ ┆ … ┆ Seating_Capac ┆ Fuel     ┆ Max_Power_(bh ┆ Max_Torque_( │
# │ ---       ┆ ---           ┆ ---        ┆ e             ┆   ┆ ity_(persons) ┆ ---      ┆ p)            ┆ Nm)          │
# │ str       ┆ str           ┆ f64        ┆ ---           ┆   ┆ ---           ┆ str      ┆ ---           ┆ ---          │
# │           ┆               ┆            ┆ str           ┆   ┆ f64           ┆          ┆ f64           ┆ f64          │
# ╞═══════════╪═══════════════╪════════════╪═══════════════╪═══╪═══════════════╪══════════╪═══════════════╪══════════════╡
# │ S2733827  ┆ Maruti Suzuki ┆ 100000.0   ┆ Not Available ┆ … ┆ NaN           ┆ Petrol   ┆ NaN           ┆ NaN          │
# ...

# %%
overview_A_2.describe()
# Out:
# shape: (9, 34)
# ┌────────────┬───────────┬────────────────┬──────────────┬───┬────────────────┬────────┬───────────────┬───────────────┐
# │ describe   ┆ profileId ┆ Car            ┆ Kilometers   ┆ … ┆ Seating_Capaci ┆ Fuel   ┆ Max_Power_(bh ┆ Max_Torque_(N │
# │ ---        ┆ ---       ┆ ---            ┆ ---          ┆   ┆ ty_(persons)   ┆ ---    ┆ p)            ┆ m)            │
# │ str        ┆ str       ┆ str            ┆ f64          ┆   ┆ ---            ┆ str    ┆ ---           ┆ ---           │
# │            ┆           ┆                ┆              ┆   ┆ f64            ┆        ┆ f64           ┆ f64           │
# ╞════════════╪═══════════╪════════════════╪══════════════╪═══╪════════════════╪════════╪═══════════════╪═══════════════╡
# │ count      ┆ 76362     ┆ 76362          ┆ 76362.0      ┆ … ┆ 76362.0        ┆ 76362  ┆ 76362.0       ┆ 76362.0       │
# ...

# %% [markdown]
# ## EXPORTING FINAL DATASET

# %%
overview_A_2.write_csv(r'C:\Users\pryns\OneDrive\Documents\Python Works\zz.carwale data\02.Pre-Processing\Pre-processed Data Stage-III\carwale_dataset.csv')
